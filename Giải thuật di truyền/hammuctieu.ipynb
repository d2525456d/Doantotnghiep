# %%
import numpy as np
import pandas as pd
import random

# %%
dt = pd.read_csv('data.csv')
dt
# Out:
#     STT                         TÊN CÔNG ĐOẠN THIẾT BỊ  TG  HỆ SỐ  TGLT  \
# 0     1                      Xã phà thun lưng       ủi   3   1.00     3
# 1     2  Lấy dấu cắt gai xù túi sau + gọt góc       tc   4   1.00     4
# 2     3               Đo cắt pat túi thân sau       tc   2   1.00     2
# 3     4      Đo cắt dây treo gắn túi thân sau       tc   5   1.00     5
# 4     6              Nối dây pat túi thân sau       1k   8   1.16    10
# ..  ...                                   ...      ...  ..    ...   ...
# 80   89                   Vệ sinh công nghiệp       tc  31   1.00    31
# 81   90           Lộn quần ( trái sang phải )       TC   5   1.00     5
# 82   91                     Mí đáy thân trước       1K  13   1.16    15
# 83   92               Lấy dấu lưng thùa khuyu       TC   9   1.00     9
# 84   93            Uỉ bao túi hông x2+túi sau       ủi  30   1.00    30
#
#     ĐƠN GIÁ  Độ khó                         Công Nhân
# 0        15       2                      Trần Thị Cúc
# 1        20       1                      Trần Thị Cúc
# 2        10       1                      Trần Thị Cúc
# 3        24       1                      Trần Thị Cúc
# 4        51       1                      Trần Thị Cúc
# ..      ...     ...                               ...
# 80      162       1  Lê Thị Thanh Hà + Nguyễn Thị Hài
# 81       25       3                  Lê Thị Như Quỳnh
# 82       80       2                   Lê Thị Thanh Hà
# 83       49       2                      Trần Thị Cúc
# 84      159       2                     Ngô Khắc Hiển
#
# [85 rows x 9 columns]

# %%
tasks_times = dt['TGLT'].dropna().tolist()

# %%
# Số thế hệ và xác suất đột biến
num_generations = 500
mutation_rate = 0.2
workers = [
    "Lê Thị Phương Thảo", "Hoàng Thị Mỹ Yến", "Trần Thị Tuyền", "Ngô Khắc Hiển",
    "Hồ Thị Diệp", "Nguyễn Thị Mỹ Nhung", "Thái Thị Nga",
    "Trần Thị Cúc", "Lê Thị Thanh Hà", "Nguyễn Thị Thúy", "Trần Thị Cẩm Rin",
    "Hoàng Thị Nở", "Lê Thị Như Quỳnh", "Trần Thị Thương", "Đinh Thị Mi",
    "Nguyễn Thị Ngọc Lan", "Bùi Thị Hồng Vân", "Trần Thị Oanh",
    "Nguyễn Thị Gấm", "Phan Thị Thu Hoài", "Nguyễn Thị Thu", "Nguyễn Thị Hài",
    "Nguyễn Thị Hồng"
]
num_workers = len(workers)

# %%
f_0 = 210.7096179
g_0 = 15255.43038
alpha = float(input('Nhập alpha: '))
# Out:
# Nhập alpha: 0.1

# %%
# Định nghĩa độ thành thạo của từng công nhân
proficiency_levels = {
    "Lê Thị Phương Thảo": 1.48,
    "Hoàng Thị Mỹ Yến": 1.16,
    "Trần Thị Tuyền": 1.48,
    "Ngô Khắc Hiển": 1.00,
    "Hồ Thị Diệp": 1.16,
    "Nguyễn Thị Mỹ Nhung": 1.16,
    "Thái Thị Nga": 1.16,
    "Trần Thị Cúc": 1.00,
    "Lê Thị Thanh Hà": 1.16,
    "Nguyễn Thị Thúy": 1.16,
    "Trần Thị Cẩm Rin": 1.32,
    "Hoàng Thị Nở": 1.16,
    "Lê Thị Như Quỳnh": 1.16,
    "Trần Thị Thương": 1.16,
    "Đinh Thị Mi": 1.16,
    "Nguyễn Thị Ngọc Lan": 1.16,
    "Bùi Thị Hồng Vân": 1.00,
    "Trần Thị Oanh": 1.16,
    "Nguyễn Thị Gấm": 1.32,
    "Phan Thị Thu Hoài": 1.16,
    "Nguyễn Thị Thu": 1.16,
    "Nguyễn Thị Hài": 1.16,
    "Nguyễn Thị Hồng": 1.48
}

# %%
# Khởi tạo quần thể
population_size = 1000

# %%
machines = [
    0, 0, 0, 0,
    1, 2, 1, 1, 0, 2, 7, 1, 7, 0, 1, 1, 2, 1, 2, 2, 1, 1, 1, 3, 2, 4, 1,
    5, 1, 1, 1, 1, 2, 7, 1, 1, 1, 1, 1, 2, 1, 1, 3, 2, 2, 7, 1, 1, 3, 7,
    6, 2, 0,
    0, 0, 2, 1,
    2, 4, 2, 4, 1, 1, 0, 1, 1, 1, 4, 0, 1, 1, 2, 0, 3, 0, 3, 1, 0, 0, 0, 0, 0, 1, 0, 0
]

# %%
# Thêm cột "Loại Máy" từ danh sách machines
dt['Loại Máy'] = machines

# Thay thế cột "TÊN CÔNG ĐOẠN" bằng chuỗi kết hợp "TÊN CÔNG ĐOẠN" và "Loại Máy"
dt['TÊN CÔNG ĐOẠN'] = dt['TÊN CÔNG ĐOẠN'] + ' - ' + dt['Loại Máy'].astype(str)

# Hiển thị DataFrame kết quả
dt
# Out:
#     STT                             TÊN CÔNG ĐOẠN THIẾT BỊ  TG  HỆ SỐ  TGLT  \
# 0     1                      Xã phà thun lưng - 0       ủi   3   1.00     3
# 1     2  Lấy dấu cắt gai xù túi sau + gọt góc - 0       tc   4   1.00     4
# 2     3               Đo cắt pat túi thân sau - 0       tc   2   1.00     2
# 3     4      Đo cắt dây treo gắn túi thân sau - 0       tc   5   1.00     5
# 4     6              Nối dây pat túi thân sau - 1       1k   8   1.16    10
# ..  ...                                       ...      ...  ..    ...   ...
# 80   89                   Vệ sinh công nghiệp - 0       tc  31   1.00    31
# 81   90           Lộn quần ( trái sang phải ) - 0       TC   5   1.00     5
# 82   91                     Mí đáy thân trước - 1       1K  13   1.16    15
# 83   92               Lấy dấu lưng thùa khuyu - 0       TC   9   1.00     9
# 84   93            Uỉ bao túi hông x2+túi sau - 0       ủi  30   1.00    30
#
#     ĐƠN GIÁ  Độ khó                         Công Nhân  Loại Máy
# 0        15       2                      Trần Thị Cúc         0
# 1        20       1                      Trần Thị Cúc         0
# 2        10       1                      Trần Thị Cúc         0
# 3        24       1                      Trần Thị Cúc         0
# 4        51       1                      Trần Thị Cúc         1
# ..      ...     ...                               ...       ...
# 80      162       1  Lê Thị Thanh Hà + Nguyễn Thị Hài         0
# 81       25       3                  Lê Thị Như Quỳnh         0
# 82       80       2                   Lê Thị Thanh Hà         1
# 83       49       2                      Trần Thị Cúc         0
# 84      159       2                     Ngô Khắc Hiển         0
#
# [85 rows x 10 columns]

# %%
f_max = 308.0681954248168
g_min = 12849.3200
f_ = f_max/f_0
g_ = g_0/g_min
print(f_)
print(g_)
lamda = g_/f_
# Out:
# 1.462050942406539
# 1.1872558532280308

# %%
def generate_population_multi():
    population = []

    for _ in range(population_size):
        individual = []
        worker_machine_assignment = {worker: set() for worker in workers}  # Theo dõi loại máy mà mỗi công nhân đã làm

        for task_idx in range(len(dt)):
            machine_type = machines[task_idx]  # Máy móc của công đoạn này
            available_workers = []

            # Chỉ chọn những công nhân có thể làm việc với loại máy này mà không vi phạm ràng buộc
            for worker in workers:
                machine_types_assigned = worker_machine_assignment[worker]
                if machine_type == 0:
                    # Nếu là máy loại 0, cho phép công nhân làm tối đa 3 loại máy
                    if len(machine_types_assigned) < 3 or machine_type in machine_types_assigned:
                        available_workers.append(worker)
                else:
                    # Nếu không phải máy loại 0, chỉ cho phép làm tối đa 2 loại máy
                    if len(machine_types_assigned) < 2 or machine_type in machine_types_assigned:
                        available_workers.append(worker)

            # Đảm bảo số lượng công nhân có thể chọn nằm trong giới hạn của available_workers
            n_selected_workers = min(len(available_workers), random.randint(1, 3))
            if n_selected_workers > 0:
                selected_workers = random.sample(available_workers, n_selected_workers)

                # Cập nhật loại máy mà các công nhân được gán làm
                for worker in selected_workers:
                    worker_machine_assignment[worker].add(machine_type)

                individual.append(selected_workers)
            else:
                # Nếu không có công nhân nào khả dụng, có thể thêm xử lý ngoại lệ
                individual.append([])  # Hoặc có thể xử lý khác nếu cần

        population.append(individual)

    return population
def calculate_total_salary(individual, proficiency_levels, dt):
    worker_salaries = {worker: 0 for worker in workers}

    for task_idx, worker_list in enumerate(individual):
        task_price = dt['ĐƠN GIÁ'][task_idx]
        num_workers = len(worker_list)
        price_per_worker = task_price / num_workers

        # Tính lương cho từng công nhân dựa trên năng lực
        for worker in worker_list:
            proficiency = proficiency_levels[worker]
            salary_for_task = price_per_worker * proficiency
            worker_salaries[worker] += salary_for_task

    # Tổng tiền lương cho tất cả công nhân trong cá thể này
    total_salary = sum(worker_salaries.values())
    return total_salary
def adjust_task_time_with_proficiency(individual):
    worker_times = {worker: 0 for worker in workers}

    for task_idx, worker_list in enumerate(individual):
        task_time = dt['TGLT'][task_idx]
        n_workers = len(worker_list)

        # Thời gian lý thuyết chia đều cho mỗi công nhân
        theoretical_time_per_worker = task_time / n_workers

        # Tính thời gian thực tế cho mỗi công nhân dựa trên độ thông thạo
        for worker in worker_list:
            worker_proficiency = proficiency_levels[worker]
            # Điều chỉnh thời gian thực tế dựa trên độ thông thạo của công nhân
            worker_time = theoretical_time_per_worker * (1 / worker_proficiency)
            worker_times[worker] += worker_time  # Lưu thời gian cho từng công nhân

    return worker_times


def display_stage_times(individual):
    detailed_task_allocation = {worker: [] for worker in workers}

    for task_idx, worker_list in enumerate(individual):
        task_time = dt['TGLT'][task_idx]
        n_workers = len(worker_list)

        # Tính thời gian chia đều lý thuyết cho mỗi công nhân
        theoretical_time_per_worker = task_time / n_workers

        # Điều chỉnh thời gian cho từng công nhân theo độ thông thạo của họ
        for worker in worker_list:
            proficiency = proficiency_levels[worker]
            worker_time = theoretical_time_per_worker / proficiency  # Điều chỉnh thời gian theo độ thông thạo
            detailed_task_allocation[worker].append(f"Công đoạn {dt['TÊN CÔNG ĐOẠN'].iloc[task_idx]}: {worker_time:.2f} giây")
    task_allocation_with_time = detailed_task_allocation
    worker_time = []

    for worker, tasks in task_allocation_with_time.items():
        # Tính tổng thời gian cho mỗi công nhân
        total_time = sum(float(task.split(": ")[1].split()[0]) for task in tasks)
        # Chi tiết các công đoạn
        task_details = " + ".join(tasks)

        worker_time.append({
            'Công Nhân': worker,
            'Tổng Thời Gian': total_time
        })
    worker_time_df =  pd.DataFrame(worker_time)

    stage_times = []

    for task_idx, worker_list in enumerate(individual):
        task_time = dt['TGLT'][task_idx]
        n_workers = len(worker_list)

        # Tính thời gian lý thuyết chia đều cho mỗi công nhân
        theoretical_time_per_worker = task_time / n_workers

        # Tính thời gian điều chỉnh cho mỗi công nhân dựa trên độ thông thạo
        worker_times = []
        for worker in worker_list:
            proficiency = proficiency_levels[worker]
            worker_time = theoretical_time_per_worker / proficiency  # Điều chỉnh thời gian theo độ thông thạo
            worker_times.append(worker_time)

        # Nếu có 1 công nhân, giữ nguyên thời gian
        if n_workers == 1:
            total_time_for_task = worker_times[0]
        # Nếu có 2 công nhân, lấy người nhanh nhất và nhân đôi thời gian
        elif n_workers == 2:
            total_time_for_task = min(worker_times) * 2
        # Nếu có 3 công nhân, lấy người nhanh nhất và nhân ba thời gian
        elif n_workers == 3:
            total_time_for_task = min(worker_times) * 3

        # Lưu trữ thời gian cho từng công đoạn
        stage_times.append(total_time_for_task)
    #tổng thời gian từng công đoạn lớn
    #lấy dấu
    total_1  =sum(stage for stage in stage_times[0:4])
    #Thân sau
    total_2  =sum(stage for stage in stage_times[4:27])
    #Thân trước
    total_3  =sum(stage for stage in stage_times[27:50])
    #Lưng
    total_4  =sum(stage for stage in stage_times[50:53])
    #quần lót
    total_5  =sum(stage for stage in stage_times[53:57])
    #hoàn thành
    total_6  =sum(stage for stage in stage_times[57:85])
    # tổng số sản phẩm trong 1 ngày
    re_stage_time = total_1+max(max(total_2,total_3)+total_4,total_5)+total_6
    total_product = (28800-re_stage_time)/worker_time_df['Tổng Thời Gian'].max()+1
    total_product

    return total_product
def calculate_total_salary(individual, proficiency_levels, dt):
    worker_salaries = {worker: 0 for worker in workers}

    for task_idx, worker_list in enumerate(individual):
        task_price = dt['ĐƠN GIÁ'][task_idx]
        num_workers = len(worker_list)
        price_per_worker = task_price / num_workers

        # Tính lương cho từng công nhân dựa trên năng lực
        for worker in worker_list:
            proficiency = proficiency_levels[worker]
            salary_for_task = price_per_worker * proficiency
            worker_salaries[worker] += salary_for_task

    # Tổng tiền lương cho tất cả công nhân trong cá thể này
    total_salary = sum(worker_salaries.values())
    return total_salary
def objective_function(individual, f_0, g_0, alpha):
    """

    Parameters:
    - f_x: Số lượng sản phẩm trong giải pháp hiện tại
    - g_x: Chi phí lương trong giải pháp hiện tại
    - f_0: Số lượng sản phẩm ban đầu (tham chiếu)
    - g_0: Chi phí lương ban đầu (tham chiếu)
    - alpha: Trọng số ưu tiên (0 <= alpha <= 1)

    Returns:
    - Giá trị của hàm mục tiêu H(x) cho giải pháp hiện tại
    """
    f_x = display_stage_times(individual)
    g_x = calculate_total_salary(individual, proficiency_levels, dt)
    normalized_product = f_x / f_0
    normalized_cost = g_0 / g_x
    H_x = (1 - alpha) * normalized_cost + lamda*alpha * normalized_product
    return H_x
def selection_multi(population):
    product_scores = [(individual, fitness_multi_with_machine_limit(individual)) for individual in population]
    # Loại bỏ các cá thể có fitness là None (không hợp lệ)
    valid_population = [(ind, score) for ind, score in product_scores if score is not None]

    # Sắp xếp theo sản lượng (càng lớn càng tốt)
    valid_population.sort(key=lambda x: x[1], reverse=True)

    # Trả về một nửa quần thể tốt nhất
    return [individual for individual, score in valid_population[:population_size // 2]]


# Giao phối (Crossover) với danh sách nhiều công nhân trên mỗi công đoạn
def crossover_multi(parent1, parent2):
    point = random.randint(1, len(dt) - 2)
    child1 = parent1[:point] + parent2[point:]
    child2 = parent2[:point] + parent1[point:]
    return child1, child2

# Đột biến (Mutation): thay đổi ngẫu nhiên danh sách công nhân cho một công đoạn
def mutate_multi(individual):
    if random.random() < mutation_rate:
        task_idx = random.randint(0, len(dt) - 1)
        # Chọn ngẫu nhiên từ 1 đến 3 công nhân cho công đoạn này
        individual[task_idx] = random.sample(workers, random.randint(1, 3))
    return individual
# Vòng lặp chính của giải thuật di truyền với nhiều công nhân trên mỗi công đoạn
# Điều chỉnh lại hàm trả về chỉ 2 giá trị để tránh lỗi "too many values to unpack"

# %%
def fitness_multi_with_machine_limit(individual):

    # Kiểm tra ràng buộc về công nhân cho mỗi công đoạn (ít nhất một công nhân)
    for task_idx, worker_list in enumerate(individual):
        if len(worker_list) == 0:  # Công đoạn không có công nhân
            return None  # Đánh dấu là không hợp lệ

    # Kiểm tra số loại máy mà mỗi công nhân làm việc
    worker_machine_types = {worker: set() for worker in workers}

    for task_idx, worker_list in enumerate(individual):
        machine_type = machines[task_idx]
        for worker in worker_list:
            worker_machine_types[worker].add(machine_type)

    # Ràng buộc số loại máy tối đa cho mỗi công nhân
    penalty = 0
    for worker, machine_types in worker_machine_types.items():
        if 0 in machine_types:
            if len(machine_types) > 3:  # Nếu có máy loại 0, tối đa là 3 loại máy
                penalty += 1  # Đánh dấu vi phạm
        else:
            if len(machine_types) > 2:  # Nếu không có máy loại 0, tối đa là 2 loại máy
                penalty += 1  # Đánh dấu vi phạm

    if penalty > 0:
        return None  # Cá thể vi phạm, không hợp lệ
    else:
        return objective_function(individual, f_0, g_0, alpha)

# %%
best_population = []
population = generate_population_multi()
max_best_H = -2  # Khởi tạo giá trị sản lượng tối đa ban đầu
elite_population = []  # Danh sách elite_population của thế hệ trước

for generation in range(num_generations):
    # Lựa chọn các cá thể tốt nhất (không bị vi phạm)
    selected_population = selection_multi(population)

    # Giữ lại các cá thể tốt nhất từ thế hệ trước (elitism)
    elite_population = sorted(population, key=lambda ind: fitness_multi_with_machine_limit(ind) or -1, reverse=True)[:2]  # Giữ lại 2 cá thể tốt nhất

    # Giao phối và tạo thế hệ mới
    new_population = []
    while len(new_population) < population_size:
        parent1, parent2 = random.sample(selected_population, 2)
        child1, child2 = crossover_multi(parent1, parent2)
        mutated_child1 = mutate_multi(child1)
        mutated_child2 = mutate_multi(child2)

        # Kiểm tra xem cá thể có bị phạt hay không
        fitness_child1 = fitness_multi_with_machine_limit(mutated_child1)
        fitness_child2 = fitness_multi_with_machine_limit(mutated_child2)

        # Nếu cá thể bị phạt, sử dụng elite_population
        if fitness_child1 is None:  # Nếu bị phạt
            mutated_child1 = random.choice(elite_population)

        if fitness_child2 is None:  # Nếu bị phạt
            mutated_child2 = random.choice(elite_population)

        # Thêm cá thể vào thế hệ mới
        new_population.append(mutated_child1)
        new_population.append(mutated_child2)

    population = new_population

    # Lấy ra giải pháp tốt nhất trong thế hệ này
    best_individual = max(population, key=lambda ind: fitness_multi_with_machine_limit(ind) or -1)
    best_H = fitness_multi_with_machine_limit(best_individual)
    total_pro = display_stage_times(best_individual)
    total_val = calculate_total_salary(best_individual, proficiency_levels, dt)
    print(total_pro)
    print(total_val)
    # Cập nhật nếu tìm được sản lượng tốt hơn
    if best_H and max_best_H < best_H:
        max_best_H = best_H
        best_population = population

    print(f"Thế hệ {generation + 1}: H tốt nhất = {max_best_H:.4f}")
    print(f"Thế hệ {generation + 1}: H  = {best_H:.4f}")

# Lấy cá thể tốt nhất từ quần thể tốt nhất
best_individual = max(best_population, key=lambda ind: fitness_multi_with_machine_limit(ind) or -1)
# Out:
# 154.26721895635325
# 14950.600000000002
# Thế hệ 1: H tốt nhất = 0.9778
# Thế hệ 1: H  = 0.9778
# 156.55621564496957
# 14899.240000000002
# Thế hệ 2: H tốt nhất = 0.9819
# Thế hệ 2: H  = 0.9819
# 167.31226101377763
# 14929.160000000002
# Thế hệ 3: H tốt nhất = 0.9841
# Thế hệ 3: H  = 0.9841
# 156.46592080467474
# 14795.640000000001
# Thế hệ 4: H tốt nhất = 0.9883
# Thế hệ 4: H  = 0.9883
# 156.4576088449521
# 14785.773333333333
# Thế hệ 5: H tốt nhất = 0.9889
# Thế hệ 5: H  = 0.9889
# 167.1682041082436
# 14801.986666666668
# Thế hệ 6: H tốt nhất = 0.9920
# Thế hệ 6: H  = 0.9920
# 173.48945383359234
# 14818.84
# Thế hệ 7: H tốt nhất = 0.9934
# Thế hệ 7: H  = 0.9934
# 173.48945383359234
# 14814.413333333334
# Thế hệ 8: H tốt nhất = 0.9937
# Thế hệ 8: H  = 0.9937
# 183.2189801653087
# 14808.226666666667
# Thế hệ 9: H tốt nhất = 0.9978
# Thế hệ 9: H  = 0.9978
# 183.2140149737839
# 14803.960000000001
# Thế hệ 10: H tốt nhất = 0.9981
# Thế hệ 10: H  = 0.9981
# 183.2042726661708
# 14798.04
# Thế hệ 11: H tốt nhất = 0.9984
# Thế hệ 11: H  = 0.9984
# 183.61534064248409
# 14789.240000000002
# Thế hệ 12: H tốt nhất = 0.9991
# Thế hệ 12: H  = 0.9991
# 188.57711136253096
# 14803.960000000003
# Thế hệ 13: H tốt nhất = 1.0001
# Thế hệ 13: H  = 1.0001
# 188.52105686414674
# 14789.240000000002
# Thế hệ 14: H tốt nhất = 1.0010
# Thế hệ 14: H  = 1.0010
# 188.59860465178875
# 14775.640000000001
# Thế hệ 15: H tốt nhất = 1.0019
# Thế hệ 15: H  = 1.0019
# 183.5693114645882
# 14737.666666666666
# Thế hệ 16: H tốt nhất = 1.0024
# Thế hệ 16: H  = 1.0024
# 187.74352319672516
# 14745.986666666668
# Thế hệ 17: H tốt nhất = 1.0034
# Thế hệ 17: H  = 1.0034
# 187.74352319672516
# 14745.986666666666
# Thế hệ 18: H tốt nhất = 1.0034
# Thế hệ 18: H  = 1.0034
# 187.70643598893759
# 14724.066666666668
# Thế hệ 19: H tốt nhất = 1.0048
# Thế hệ 19: H  = 1.0048
# 187.6971641869907
# 14723.880000000001
# Thế hệ 20: H tốt nhất = 1.0048
# Thế hệ 20: H  = 1.0048
# 187.69498598819655
# 14709.666666666666
# Thế hệ 21: H tốt nhất = 1.0057
# Thế hệ 21: H  = 1.0057
# 195.9755605765946
# 14753.826666666664
# Thế hệ 22: H tốt nhất = 1.0061
# Thế hệ 22: H  = 1.0061
# 187.69498598819655
# 14690.626666666665
# Thế hệ 23: H tốt nhất = 1.0069
# Thế hệ 23: H  = 1.0069
# 187.66826931980071
# 14680.466666666665
# Thế hệ 24: H tốt nhất = 1.0076
# Thế hệ 24: H  = 1.0076
# 199.48171689120184
# 14731.266666666666
# Thế hệ 25: H tốt nhất = 1.0089
# Thế hệ 25: H  = 1.0089
# 199.45331771042356
# 14719.106666666667
# Thế hệ 26: H tốt nhất = 1.0097
# Thế hệ 26: H  = 1.0097
# 199.48171689120184
# 14712.226666666666
# Thế hệ 27: H tốt nhất = 1.0101
# Thế hệ 27: H  = 1.0101
# 199.45331771042356
# 14700.066666666666
# Thế hệ 28: H tốt nhất = 1.0109
# Thế hệ 28: H  = 1.0109
# 199.42526686014543
# 14689.719999999998
# Thế hệ 29: H tốt nhất = 1.0115
# Thế hệ 29: H  = 1.0115
# 199.42526686014543
# 14689.719999999998
# Thế hệ 30: H tốt nhất = 1.0115
# Thế hệ 30: H  = 1.0115
# 199.4017647963989
# 14681.08
# Thế hệ 31: H tốt nhất = 1.0121
# Thế hệ 31: H  = 1.0121
# 199.42526686014543
# 14677.559999999998
# Thế hệ 32: H tốt nhất = 1.0123
# Thế hệ 32: H  = 1.0123
# 201.11500359961695
# 14681.079999999998
# Thế hệ 33: H tốt nhất = 1.0127
# Thế hệ 33: H  = 1.0127
# 201.1387086083706
# 14677.559999999998
# Thế hệ 34: H tốt nhất = 1.0130
# Thế hệ 34: H  = 1.0130
# 201.11500359961695
# 14668.919999999998
# Thế hệ 35: H tốt nhất = 1.0135
# Thế hệ 35: H  = 1.0135
# 205.29303979116415
# 14675.319999999998
# Thế hệ 36: H tốt nhất = 1.0147
# Thế hệ 36: H  = 1.0147
# 199.36467784314584
# 14627.8
# Thế hệ 37: H tốt nhất = 1.0154
# Thế hệ 37: H  = 1.0154
# 201.08441649154773
# 14635.48
# Thế hệ 38: H tốt nhất = 1.0156
# Thế hệ 38: H  = 1.0156
# 201.03258374354934
# 14614.253333333334
# Thế hệ 39: H tốt nhất = 1.0170
# Thế hệ 39: H  = 1.0170
# 201.25239976964116
# 14614.253333333334
# Thế hệ 40: H tốt nhất = 1.0170
# Thế hệ 40: H  = 1.0170
# 201.03258374354934
# 14607.85333333333
# Thế hệ 41: H tốt nhất = 1.0174
# Thế hệ 41: H  = 1.0174
# 201.03258374354934
# 14607.85333333333
# Thế hệ 42: H tốt nhất = 1.0174
# Thế hệ 42: H  = 1.0174
# 201.0284916844968
# 14604.653333333332
# Thế hệ 43: H tốt nhất = 1.0176
# Thế hệ 43: H  = 1.0176
# 201.03258374354934
# 14597.399999999998
# Thế hệ 44: H tốt nhất = 1.0180
# Thế hệ 44: H  = 1.0180
# 201.01270212330434
# 14596.813333333332
# Thế hệ 45: H tốt nhất = 1.0181
# Thế hệ 45: H  = 1.0181
# 201.00861006425183
# 14593.613333333333
# Thế hệ 46: H tốt nhất = 1.0183
# Thế hệ 46: H  = 1.0183
# 201.23249630146182
# 14589.56
# Thế hệ 47: H tốt nhất = 1.0186
# Thế hệ 47: H  = 1.0186
# 201.00861006425183
# 14583.16
# Thế hệ 48: H tốt nhất = 1.0190
# Thế hệ 48: H  = 1.0190
# 201.00861006425183
# 14580.919999999998
# Thế hệ 49: H tốt nhất = 1.0191
# Thế hệ 49: H  = 1.0191
# 202.92688421647824
# 14586.279999999997
# Thế hệ 50: H tốt nhất = 1.0195
# Thế hệ 50: H  = 1.0195
# 202.90647779122108
# 14583.16
# Thế hệ 51: H tốt nhất = 1.0197
# Thế hệ 51: H  = 1.0197
# 203.4531597428149
# 14584.36
# Thế hệ 52: H tốt nhất = 1.0198
# Thế hệ 52: H  = 1.0198
# 205.18859047303715
# 14587.559999999998
# Thế hệ 53: H tốt nhất = 1.0203
# Thế hệ 53: H  = 1.0203
# 205.18441250031208
# 14583.160000000002
# Thế hệ 54: H tốt nhất = 1.0206
# Thế hệ 54: H  = 1.0206
# 205.18441250031208
# 14582.119999999999
# Thế hệ 55: H tốt nhất = 1.0206
# Thế hệ 55: H  = 1.0206
# 211.27489474372655
# 14611.800000000001
# Thế hệ 56: H tốt nhất = 1.0211
# Thế hệ 56: H  = 1.0211
# 207.25790476709608
# 14581.880000000001
# Thế hệ 57: H tốt nhất = 1.0214
# Thế hệ 57: H  = 1.0214
# 207.25790476709608
# 14581.880000000001
# Thế hệ 58: H tốt nhất = 1.0214
# Thế hệ 58: H  = 1.0214
# 211.2523919971416
# 14594.6
# Thế hệ 59: H tốt nhất = 1.0222
# Thế hệ 59: H  = 1.0222
# 211.23187759859812
# 14584.866666666667
# Thế hệ 60: H tốt nhất = 1.0228
# Thế hệ 60: H  = 1.0228
# 214.25459141470378
# 14600.039999999999
# Thế hệ 61: H tốt nhất = 1.0230
# Thế hệ 61: H  = 1.0230
# 211.21753855022195
# 14581.026666666667
# Thế hệ 62: H tốt nhất = 1.0230
# Thế hệ 62: H  = 1.0230
# 214.24731951669187
# 14597.266666666668
# Thế hệ 63: H tốt nhất = 1.0231
# Thế hệ 63: H  = 1.0231
# 216.198314721801
# 14596.039999999999
# Thế hệ 64: H tốt nhất = 1.0240
# Thế hệ 64: H  = 1.0240
# 216.19337803481164
# 14595.480000000001
# Thế hệ 65: H tốt nhất = 1.0240
# Thế hệ 65: H  = 1.0240
# 216.18603971631396
# 14592.706666666669
# Thế hệ 66: H tốt nhất = 1.0242
# Thế hệ 66: H  = 1.0242
# 216.18192581048947
# 14588.706666666669
# Thế hệ 67: H tốt nhất = 1.0244
# Thế hệ 67: H  = 1.0244
# 216.16602612041115
# 14581.0
# Thế hệ 68: H tốt nhất = 1.0249
# Thế hệ 68: H  = 1.0249
# 216.16602612041115
# 14581.0
# Thế hệ 69: H tốt nhất = 1.0249
# Thế hệ 69: H  = 1.0249
# 216.1569755275973
# 14576.44
# Thế hệ 70: H tốt nhất = 1.0252
# Thế hệ 70: H  = 1.0252
# 216.1569755275973
# 14575.106666666668
# Thế hệ 71: H tốt nhất = 1.0253
# Thế hệ 71: H  = 1.0253
# 216.1569755275973
# 14573.400000000001
# Thế hệ 72: H tốt nhất = 1.0254
# Thế hệ 72: H  = 1.0254
# 216.1569755275973
# 14573.400000000001
# Thế hệ 73: H tốt nhất = 1.0254
# Thế hệ 73: H  = 1.0254
# 216.1496372090996
# 14571.266666666666
# Thế hệ 74: H tốt nhất = 1.0256
# Thế hệ 74: H  = 1.0256
# 217.01329221473694
# 14575.533333333335
# Thế hệ 75: H tốt nhất = 1.0256
# Thế hệ 75: H  = 1.0256
# 217.00739835576962
# 14572.866666666669
# Thế hệ 76: H tốt nhất = 1.0258
# Thế hệ 76: H  = 1.0258
# 217.00047307148304
# 14569.133333333333
# Thế hệ 77: H tốt nhất = 1.0260
# Thế hệ 77: H  = 1.0260
# 217.00047307148304
# 14569.133333333333
# Thế hệ 78: H tốt nhất = 1.0260
# Thế hệ 78: H  = 1.0260
# 216.99457921251567
# 14566.999999999998
# Thế hệ 79: H tốt nhất = 1.0262
# Thế hệ 79: H  = 1.0262
# 217.56542635763338
# 14570.333333333332
# Thế hệ 80: H tốt nhất = 1.0262
# Thế hệ 80: H  = 1.0262
# 217.55951708316744
# 14568.199999999997
# Thế hệ 81: H tốt nhất = 1.0263
# Thế hệ 81: H  = 1.0263
# 219.33748215744993
# 14574.066666666668
# Thế hệ 82: H tốt nhất = 1.0266
# Thế hệ 82: H  = 1.0266
# 219.33748215744993
# 14574.066666666668
# Thế hệ 83: H tốt nhất = 1.0266
# Thế hệ 83: H  = 1.0266
# 219.33748215744993
# 14574.066666666668
# Thế hệ 84: H tốt nhất = 1.0266
# Thế hệ 84: H  = 1.0266
# 219.33450343927427
# 14572.466666666667
# Thế hệ 85: H tốt nhất = 1.0267
# Thế hệ 85: H  = 1.0267
# 219.33450343927427
# 14572.466666666667
# Thế hệ 86: H tốt nhất = 1.0267
# Thế hệ 86: H  = 1.0267
# 219.33450343927427
# 14572.466666666667
# Thế hệ 87: H tốt nhất = 1.0267
# Thế hệ 87: H  = 1.0267
# 219.3300353620108
# 14571.506666666666
# Thế hệ 88: H tốt nhất = 1.0268
# Thế hệ 88: H  = 1.0268
# 219.3270566438351
# 14569.906666666666
# Thế hệ 89: H tốt nhất = 1.0269
# Thế hệ 89: H  = 1.0269
# 219.3270566438351
# 14569.906666666666
# Thế hệ 90: H tốt nhất = 1.0269
# Thế hệ 90: H  = 1.0269
# 219.3270566438351
# 14569.906666666666
# Thế hệ 91: H tốt nhất = 1.0269
# Thế hệ 91: H  = 1.0269
# 219.58904911180773
# 14569.906666666668
# Thế hệ 92: H tốt nhất = 1.0270
# Thế hệ 92: H  = 1.0270
# 219.58904911180773
# 14569.906666666668
# Thế hệ 93: H tốt nhất = 1.0270
# Thế hệ 93: H  = 1.0270
# 219.58904911180773
# 14568.573333333334
# Thế hệ 94: H tốt nhất = 1.0271
# Thế hệ 94: H  = 1.0271
# 219.58904911180773
# 14568.573333333334
# Thế hệ 95: H tốt nhất = 1.0271
# Thế hệ 95: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 96: H tốt nhất = 1.0271
# Thế hệ 96: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 97: H tốt nhất = 1.0271
# Thế hệ 97: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 98: H tốt nhất = 1.0271
# Thế hệ 98: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 99: H tốt nhất = 1.0271
# Thế hệ 99: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 100: H tốt nhất = 1.0271
# Thế hệ 100: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 101: H tốt nhất = 1.0271
# Thế hệ 101: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 102: H tốt nhất = 1.0271
# Thế hệ 102: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 103: H tốt nhất = 1.0271
# Thế hệ 103: H  = 1.0271
# 219.58904911180773
# 14568.57333333333
# Thế hệ 104: H tốt nhất = 1.0271
# Thế hệ 104: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 105: H tốt nhất = 1.0271
# Thế hệ 105: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 106: H tốt nhất = 1.0271
# Thế hệ 106: H  = 1.0271
# 219.58904911180773
# 14568.573333333332
# Thế hệ 107: H tốt nhất = 1.0271
# Thế hệ 107: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 108: H tốt nhất = 1.0271
# Thế hệ 108: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 109: H tốt nhất = 1.0271
# Thế hệ 109: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 110: H tốt nhất = 1.0271
# Thế hệ 110: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 111: H tốt nhất = 1.0271
# Thế hệ 111: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 112: H tốt nhất = 1.0271
# Thế hệ 112: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 113: H tốt nhất = 1.0271
# Thế hệ 113: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 114: H tốt nhất = 1.0271
# Thế hệ 114: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 115: H tốt nhất = 1.0271
# Thế hệ 115: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 116: H tốt nhất = 1.0271
# Thế hệ 116: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 117: H tốt nhất = 1.0271
# Thế hệ 117: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 118: H tốt nhất = 1.0271
# Thế hệ 118: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 119: H tốt nhất = 1.0271
# Thế hệ 119: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 120: H tốt nhất = 1.0271
# Thế hệ 120: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 121: H tốt nhất = 1.0271
# Thế hệ 121: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 122: H tốt nhất = 1.0271
# Thế hệ 122: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 123: H tốt nhất = 1.0271
# Thế hệ 123: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 124: H tốt nhất = 1.0271
# Thế hệ 124: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 125: H tốt nhất = 1.0271
# Thế hệ 125: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 126: H tốt nhất = 1.0271
# Thế hệ 126: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 127: H tốt nhất = 1.0271
# Thế hệ 127: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 128: H tốt nhất = 1.0271
# Thế hệ 128: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 129: H tốt nhất = 1.0271
# Thế hệ 129: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 130: H tốt nhất = 1.0271
# Thế hệ 130: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 131: H tốt nhất = 1.0271
# Thế hệ 131: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 132: H tốt nhất = 1.0271
# Thế hệ 132: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 133: H tốt nhất = 1.0271
# Thế hệ 133: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 134: H tốt nhất = 1.0271
# Thế hệ 134: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 135: H tốt nhất = 1.0271
# Thế hệ 135: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 136: H tốt nhất = 1.0271
# Thế hệ 136: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 137: H tốt nhất = 1.0271
# Thế hệ 137: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 138: H tốt nhất = 1.0271
# Thế hệ 138: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 139: H tốt nhất = 1.0271
# Thế hệ 139: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 140: H tốt nhất = 1.0271
# Thế hệ 140: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 141: H tốt nhất = 1.0271
# Thế hệ 141: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 142: H tốt nhất = 1.0271
# Thế hệ 142: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 143: H tốt nhất = 1.0271
# Thế hệ 143: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 144: H tốt nhất = 1.0271
# Thế hệ 144: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 145: H tốt nhất = 1.0271
# Thế hệ 145: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 146: H tốt nhất = 1.0271
# Thế hệ 146: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 147: H tốt nhất = 1.0271
# Thế hệ 147: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 148: H tốt nhất = 1.0271
# Thế hệ 148: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 149: H tốt nhất = 1.0271
# Thế hệ 149: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 150: H tốt nhất = 1.0271
# Thế hệ 150: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 151: H tốt nhất = 1.0271
# Thế hệ 151: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 152: H tốt nhất = 1.0271
# Thế hệ 152: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 153: H tốt nhất = 1.0271
# Thế hệ 153: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 154: H tốt nhất = 1.0271
# Thế hệ 154: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 155: H tốt nhất = 1.0271
# Thế hệ 155: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 156: H tốt nhất = 1.0271
# Thế hệ 156: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 157: H tốt nhất = 1.0271
# Thế hệ 157: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 158: H tốt nhất = 1.0271
# Thế hệ 158: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 159: H tốt nhất = 1.0271
# Thế hệ 159: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 160: H tốt nhất = 1.0271
# Thế hệ 160: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 161: H tốt nhất = 1.0271
# Thế hệ 161: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 162: H tốt nhất = 1.0271
# Thế hệ 162: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 163: H tốt nhất = 1.0271
# Thế hệ 163: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 164: H tốt nhất = 1.0271
# Thế hệ 164: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 165: H tốt nhất = 1.0271
# Thế hệ 165: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 166: H tốt nhất = 1.0271
# Thế hệ 166: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 167: H tốt nhất = 1.0271
# Thế hệ 167: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 168: H tốt nhất = 1.0271
# Thế hệ 168: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 169: H tốt nhất = 1.0271
# Thế hệ 169: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 170: H tốt nhất = 1.0271
# Thế hệ 170: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 171: H tốt nhất = 1.0271
# Thế hệ 171: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 172: H tốt nhất = 1.0271
# Thế hệ 172: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 173: H tốt nhất = 1.0271
# Thế hệ 173: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 174: H tốt nhất = 1.0271
# Thế hệ 174: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 175: H tốt nhất = 1.0271
# Thế hệ 175: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 176: H tốt nhất = 1.0271
# Thế hệ 176: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 177: H tốt nhất = 1.0271
# Thế hệ 177: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 178: H tốt nhất = 1.0271
# Thế hệ 178: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 179: H tốt nhất = 1.0271
# Thế hệ 179: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 180: H tốt nhất = 1.0271
# Thế hệ 180: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 181: H tốt nhất = 1.0271
# Thế hệ 181: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 182: H tốt nhất = 1.0271
# Thế hệ 182: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 183: H tốt nhất = 1.0271
# Thế hệ 183: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 184: H tốt nhất = 1.0271
# Thế hệ 184: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 185: H tốt nhất = 1.0271
# Thế hệ 185: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 186: H tốt nhất = 1.0271
# Thế hệ 186: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 187: H tốt nhất = 1.0271
# Thế hệ 187: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 188: H tốt nhất = 1.0271
# Thế hệ 188: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 189: H tốt nhất = 1.0271
# Thế hệ 189: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 190: H tốt nhất = 1.0271
# Thế hệ 190: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 191: H tốt nhất = 1.0271
# Thế hệ 191: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 192: H tốt nhất = 1.0271
# Thế hệ 192: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 193: H tốt nhất = 1.0271
# Thế hệ 193: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 194: H tốt nhất = 1.0271
# Thế hệ 194: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 195: H tốt nhất = 1.0271
# Thế hệ 195: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 196: H tốt nhất = 1.0271
# Thế hệ 196: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 197: H tốt nhất = 1.0271
# Thế hệ 197: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 198: H tốt nhất = 1.0271
# Thế hệ 198: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 199: H tốt nhất = 1.0271
# Thế hệ 199: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 200: H tốt nhất = 1.0271
# Thế hệ 200: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 201: H tốt nhất = 1.0271
# Thế hệ 201: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 202: H tốt nhất = 1.0271
# Thế hệ 202: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 203: H tốt nhất = 1.0271
# Thế hệ 203: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 204: H tốt nhất = 1.0271
# Thế hệ 204: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 205: H tốt nhất = 1.0271
# Thế hệ 205: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 206: H tốt nhất = 1.0271
# Thế hệ 206: H  = 1.0271
# 219.58904911180773
# 14568.573333333328
# Thế hệ 207: H tốt nhất = 1.0271
# Thế hệ 207: H  = 1.0271
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-118-75e35a02ba74> in <cell line: 6>()
#      21         # Kiểm tra xem cá thể có bị phạt hay không
#      22         fitness_child1 = fitness_multi_with_machine_limit(mutated_child1)
# ---> 23         fitness_child2 = fitness_multi_with_machine_limit(mutated_child2)
#      24
#      25         # Nếu cá thể bị phạt, sử dụng elite_population
#
# <ipython-input-117-44dbd01116e1> in fitness_multi_with_machine_limit(individual)
#      27         return None  # Cá thể vi phạm, không hợp lệ
#      28     else:
# ---> 29         return objective_function(individual, f_0, g_0, alpha)
#
# <ipython-input-116-6622c5c89714> in objective_function(individual, f_0, g_0, alpha)
#     184     """
#     185     f_x = display_stage_times(individual)
# --> 186     g_x = calculate_total_salary(individual, proficiency_levels, dt)
#     187     normalized_product = f_x / f_0
#     188     normalized_cost = g_0 / g_x
#
# <ipython-input-116-6622c5c89714> in calculate_total_salary(individual, proficiency_levels, dt)
#     157
#     158     for task_idx, worker_list in enumerate(individual):
# --> 159         task_price = dt['ĐƠN GIÁ'][task_idx]
#     160         num_workers = len(worker_list)
#     161         price_per_worker = task_price / num_workers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4073             if not is_mi and (
#    4074                 self.columns.is_unique
# -> 4075                 and key in self.columns
#    4076                 or key in self.columns.drop_duplicates(keep=False)
#    4077             ):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    5321         return is_object_dtype(self.dtype)
#    5322
# -> 5323     def __contains__(self, key: Any) -> bool:
#    5324         """
#    5325         Return a boolean indicating whether the provided key is in the index.
#
# KeyboardInterrupt:

# %%
# Lấy cá thể tốt nhất từ quần thể tốt nhất
best_individual = max(best_population, key=lambda ind: fitness_multi_with_machine_limit(ind) or float('inf'))

# Gán lời giải tốt nhất (nhiều công nhân trên mỗi công đoạn) vào bảng kết quả
dt['Công Nhân Mới (Nhiều)'] = [", ".join(worker_list) for worker_list in best_individual]

# Hiển thị kết quả cuối cùng
dt[['TÊN CÔNG ĐOẠN', 'Công Nhân Mới (Nhiều)']]
# Out:
#                                TÊN CÔNG ĐOẠN  \
# 0                       Xã phà thun lưng - 0
# 1   Lấy dấu cắt gai xù túi sau + gọt góc - 0
# 2                Đo cắt pat túi thân sau - 0
# 3       Đo cắt dây treo gắn túi thân sau - 0
# 4               Nối dây pat túi thân sau - 1
# ..                                       ...
# 80                   Vệ sinh công nghiệp - 0
# 81           Lộn quần ( trái sang phải ) - 0
# 82                     Mí đáy thân trước - 1
# 83               Lấy dấu lưng thùa khuyu - 0
# 84            Uỉ bao túi hông x2+túi sau - 0
#
#                                 Công Nhân Mới (Nhiều)
# 0               Hoàng Thị Mỹ Yến, Nguyễn Thị Ngọc Lan
# 1                    Ngô Khắc Hiển, Phan Thị Thu Hoài
# 2                  Trần Thị Oanh, Nguyễn Thị Mỹ Nhung
# 3                                     Nguyễn Thị Thúy
# 4                 Lê Thị Như Quỳnh, Phan Thị Thu Hoài
# ..                                                ...
# 80                       Hoàng Thị Nở, Nguyễn Thị Hài
# 81  Nguyễn Thị Hài, Ngô Khắc Hiển, Nguyễn Thị Ngọc...
# 82                                      Trần Thị Oanh
# 83                     Trần Thị Oanh, Nguyễn Thị Thúy
# 84                   Ngô Khắc Hiển, Phan Thị Thu Hoài
#
# [85 rows x 2 columns]

# %%
# Hàm tính lương và tổng tiền lương cho tất cả công nhân
def calculate_salary(individual, proficiency_levels, dt):
    worker_salaries = {worker: 0 for worker in workers}  # Khởi tạo lương cho mỗi công nhân bằng 0

    for task_idx, worker_list in enumerate(individual):
        # Lấy đơn giá của công đoạn hiện tại
        task_price = dt['ĐƠN GIÁ'][task_idx]
        num_workers = len(worker_list)  # Số công nhân thực hiện công đoạn

        # Chia đơn giá cho số công nhân nếu nhiều người thực hiện
        price_per_worker = task_price / num_workers

        # Tính lương cho từng công nhân tham gia công đoạn
        for worker in worker_list:
            proficiency = proficiency_levels[worker]  # Lấy năng lực của công nhân
            # Lương cho công đoạn này bằng đơn giá chia cho số công nhân, sau đó nhân năng lực
            salary_for_task = price_per_worker * proficiency
            # Cộng lương cho công đoạn này vào tổng lương của công nhân
            worker_salaries[worker] += salary_for_task

    # Tạo DataFrame chứa kết quả lương của từng công nhân
    salary_df = pd.DataFrame.from_dict(worker_salaries, orient='index', columns=['Tiền Lương'])
    salary_df.reset_index(inplace=True)
    salary_df.columns = ['Công Nhân', 'Tổng Tiền Lương']

    # Tính tổng tiền lương của tất cả công nhân
    total_salary = salary_df['Tổng Tiền Lương'].sum()
    print(f"Tổng tiền lương của tất cả công nhân: {total_salary:.2f}")

    return salary_df, total_salary
# Sử dụng hàm để tính lương cho mỗi công nhân và tổng lương
salary_df, total_salary = calculate_salary(best_individual, proficiency_levels, dt)

# Hiển thị DataFrame chứa tổng tiền lương cho mỗi công nhân
print(salary_df)
print(f"Tổng tiền lương của tất cả công nhân: {total_salary:.2f}")

# # Giả sử calculate_salary trả về (worker_salaries, total_salary)
# worker_salaries, total_salary = calculate_salary(best_individual, proficiency_levels, dt)

# # In tổng tiền lương của tất cả công nhân
# print(f"Tổng tiền lương của tất cả công nhân: {total_salary:.2f}")

# # In chi tiết lương của từng công nhân
# print("Chi tiết lương của từng công nhân:")
# for worker, row in worker_salaries.iterrows():  # iterrows() giúp lặp qua từng hàng trong DataFrame
#     salary = row['Tổng Tiền Lương']  # Lấy giá trị lương từ cột 'Tổng Tiền Lương'
#     print(f"Công nhân {worker}: Lương = {salary:.2f}")
# Out:
# Tổng tiền lương của tất cả công nhân: 14568.57
#               Công Nhân  Tổng Tiền Lương
# 0    Lê Thị Phương Thảo         0.000000
# 1      Hoàng Thị Mỹ Yến       842.353333
# 2        Trần Thị Tuyền         0.000000
# 3         Ngô Khắc Hiển       658.166667
# 4           Hồ Thị Diệp       791.120000
# 5   Nguyễn Thị Mỹ Nhung       828.046667
# 6          Thái Thị Nga       817.220000
# 7          Trần Thị Cúc       661.000000
# 8       Lê Thị Thanh Hà       874.253333
# 9       Nguyễn Thị Thúy       877.926667
# 10     Trần Thị Cẩm Rin         0.000000
# 11         Hoàng Thị Nở       771.013333
# 12     Lê Thị Như Quỳnh       817.993333
# 13      Trần Thị Thương       849.700000
# 14          Đinh Thị Mi       858.980000
# 15  Nguyễn Thị Ngọc Lan       392.273333
# 16     Bùi Thị Hồng Vân       666.000000
# 17        Trần Thị Oanh       831.526667
# 18       Nguyễn Thị Gấm       611.820000
# 19    Phan Thị Thu Hoài       786.480000
# 20       Nguyễn Thị Thu       779.906667
# 21       Nguyễn Thị Hài       852.793333
# 22      Nguyễn Thị Hồng         0.000000
# Tổng tiền lương của tất cả công nhân: 14568.57

# %%
def display_worker_tasks(individual):
    # Tạo một dictionary lưu trữ các công đoạn mà mỗi công nhân đảm nhiệm
    worker_tasks = {worker: [] for worker in workers}

    # Lặp qua từng công đoạn trong cá thể tốt nhất
    for task_idx, worker_list in enumerate(individual):
        # Lấy tên công đoạn và loại máy cho công đoạn hiện tại
        task_name = dt['TÊN CÔNG ĐOẠN'].iloc[task_idx]  # Sử dụng iloc để tránh lỗi index
        machine_type = machines[task_idx]

        # Thêm công đoạn và loại máy vào danh sách công việc của từng công nhân
        for worker in worker_list:
            worker_tasks[worker].append(f"{task_name} (Máy {machine_type})")

    # Hiển thị kết quả
    for worker, tasks in worker_tasks.items():
        if tasks:  # Nếu công nhân có công việc
            tasks_str = ", ".join(tasks)
            print(f"Công nhân {worker} làm các công đoạn: {tasks_str}")
        else:
            print(f"Công nhân {worker} không có công việc.")

# Gọi hàm hiển thị công việc của từng công nhân cho cá thể tốt nhất
best_individual = max(best_population, key=fitness_multi_with_machine_limit)


display_worker_tasks(best_individual)
# Out:
# Công nhân Lê Thị Phương Thảo không có công việc.
# Công nhân Hoàng Thị Mỹ Yến làm các công đoạn: Xã phà thun lưng - 0 (Máy 0), Chốt pat túi thân sau - 1 (Máy 1), Ép keo cơi túi - 2 (Máy 2), Cuốn miệng túi đồng hồ - 1 (Máy 1), Vs3c bao túi hông x2+lộn - 2 (Máy 2), Chạy thun ống quần x2 + cắt + đo quần - 2 (Máy 2), Vs4c đáy trong - 2 (Máy 2), Gấp đôi bấm dấu nhãn tp - 0 (Máy 0), Ghim thun lưng 1 điểm + lấy dấu ( sau ) - 1 (Máy 1), Lấy dấu quần lót - 1 (Máy 1), Cắt chỉ + gọt lươc gà túi sau - 0 (Máy 0)
# Công nhân Trần Thị Tuyền không có công việc.
# Công nhân Ngô Khắc Hiển làm các công đoạn: Lấy dấu cắt gai xù túi sau + gọt góc - 0 (Máy 0), Bấm góc túi thân sau + chốt 2 đầu cơi túi vào lót túi - 0 (Máy 0), Lượ số vs5c decuop vào túi thân sau - 2 (Máy 2), Lựa số+ ghim miệng túi hông vào đáp túi x4 - 1 (Máy 1), Vs3c bao túi hông x2+lộn - 2 (Máy 2), Mí nhãn tp - 0 (Máy 0), Lộn quần ( trái sang phải ) - 0 (Máy 0), Uỉ bao túi hông x2+túi sau - 0 (Máy 0)
# Công nhân Hồ Thị Diệp làm các công đoạn: Kẹp mí đáp túi + bỏ dây treo thân sau + đo gọt đây treo + lấy dấu đáp túi - 1 (Máy 1), Lựa số + vss5c đecup thân sau - 2 (Máy 2), May nhãn cơi túi thân sau - 1 (Máy 1), Vs3c xq túi đồng hồ - 2 (Máy 2), Bấm góc miệng túi hông x4 - 1 (Máy 1), Bấm góc vs3c đáy tt - 2 (Máy 2), Kansai 2 kim ssays thân trước - 1 (Máy 1), Nối thun lưng + cắt - 2 (Máy 2), Vs4c quần lót vào quần - 2 (Máy 2)
# Công nhân Nguyễn Thị Mỹ Nhung làm các công đoạn: Đo cắt pat túi thân sau - 0 (Máy 0), Chốt dây treo túi sau - 1 (Máy 1), Bỏ rập đh cơi túi ( xù, pat, lược tp cơi) - 7 (Máy 7), Láy dấu may gai đáp túi thân sau - 1 (Máy 1), May nhãn logo thân trước + lấy dấu - 7 (Máy 7), Lấy dấu thun lưng + kéo - 0 (Máy 0), Kansai thun ống quần x2 + lộn - 1 (Máy 1), Lấy dấu laix2 ( sườn trong , ngoài) - 0 (Máy 0)
# Công nhân Thái Thị Nga làm các công đoạn: Kẹp mí đáp túi + bỏ dây treo thân sau + đo gọt đây treo + lấy dấu đáp túi - 1 (Máy 1), Kẹp mí đáp túi to x2 - 1 (Máy 1), diễu kan sai đáy trong - 4 (Máy 4), Lược nhãn tp - 1 (Máy 1), Ghim thun lưng 3 điểm + lấy dấu ( trước + sườn ) - 1 (Máy 1)
# Công nhân Trần Thị Cúc làm các công đoạn: Bỏ rập đh cơi túi ( xù, pat, lược tp cơi) - 7 (Máy 7), Bỏ rập dh túi thân sau + lụa số - 7 (Máy 7), Vs3c bao túi thân sau + lộn - 2 (Máy 2), Lựa số+ bỏ rập đh tt + lấy dấu + paget - 7 (Máy 7), May nhãn logo thân trước + lấy dấu - 7 (Máy 7), Vs4c quần lót vào quần - 2 (Máy 2)
# Công nhân Lê Thị Thanh Hà làm các công đoạn: Vs3c xq túi đồng hồ - 2 (Máy 2), Lấy dấu may nhãn lưng - 1 (Máy 1), May lai quần tp x2 - 1 (Máy 1)
# Công nhân Nguyễn Thị Thúy làm các công đoạn: Đo cắt dây treo gắn túi thân sau - 0 (Máy 0), Ép dây pat túi thân sau - 2 (Máy 2), Vs3c bao túi thân sau + lộn - 2 (Máy 2), Dieux 2k decuop thân sau x2 - 1 (Máy 1), Lựa số + vs4c sườn thân x2+CANH SỌC - 2 (Máy 2), Lấy dấu lưng thùa khuyu - 0 (Máy 0)
# Công nhân Trần Thị Cẩm Rin không có công việc.
# Công nhân Hoàng Thị Nở làm các công đoạn: Ép keo cơi túi - 2 (Máy 2), Ghim miêng túi thân sau vào đáp túi - 1 (Máy 1), Lựa số đóng túi nhỏ vào bao túi - 1 (Máy 1), Lược bao túi vào thân x2 - 1 (Máy 1), Vs3c bao túi hông x2+lộn - 2 (Máy 2), Lược bao túi vào đáy thân trước + 1 đoan paget - 1 (Máy 1), Kansai 2 kim ssays thân trước - 1 (Máy 1), Vs4c đáy trong - 2 (Máy 2), Mí nhãn tp - 0 (Máy 0), Vệ sinh công nghiệp - 0 (Máy 0)
# Công nhân Lê Thị Như Quỳnh làm các công đoạn: Nối dây pat túi thân sau - 1 (Máy 1), Bỏ rập đh cơi túi ( xù, pat, lược tp cơi) - 7 (Máy 7), Mí túi thân sau - 1 (Máy 1), Bỏ rập đh túi hông x2 + lấy dấu + canh sọc - 7 (Máy 7), Lược bao túi vào đáy thân trước + 1 đoan paget - 1 (Máy 1), Lựa số+ bỏ rập đh tt + lấy dấu + paget - 7 (Máy 7), May nhãn logo thân trước + lấy dấu - 7 (Máy 7), Xã phà thun ống quần - 0 (Máy 0), Lấy dấu quần lót - 1 (Máy 1)
# Công nhân Trần Thị Thương làm các công đoạn: Bọ túi thân sau x2 - 3 (Máy 3), Kẹp mí đáp túi to x2 - 1 (Máy 1), Cuốn miệng túi đồng hồ - 1 (Máy 1), Mí âm miêng túi hông x2 - 1 (Máy 1), Diễu 6 ly bao túi hông x2 + lộn - 1 (Máy 1), Bọ paget tròn x2 - 3 (Máy 3), Mí nhãn tp - 0 (Máy 0), Thắt nơ dây luồn quần - 0 (Máy 0)
# Công nhân Đinh Thị Mi làm các công đoạn: Bấm góc túi thân sau + chốt 2 đầu cơi túi vào lót túi - 0 (Máy 0), Mí túi thân sau - 1 (Máy 1), Ghim miêng túi thân sau vào đáp túi - 1 (Máy 1), Kẹp mí đáp túi nhỏ x2 - 1 (Máy 1), Bấm góc miệng túi hông x4 - 1 (Máy 1), Diễu 6 ly miệng túi x2 - 1 (Máy 1), Lấy dấu laix2 ( sườn trong , ngoài) - 0 (Máy 0)
# Công nhân Nguyễn Thị Ngọc Lan làm các công đoạn: Xã phà thun lưng - 0 (Máy 0), Lựa số+ bỏ rập đh tt + lấy dấu + paget - 7 (Máy 7), Thùa khuyu lưng x2 - 6 (Máy 6), Lấy dấu thun lưng + kéo - 0 (Máy 0), Vs4c sườn thân x2 - 0 (Máy 0), Lộn quần ( trái sang phải ) - 0 (Máy 0)
# Công nhân Bùi Thị Hồng Vân làm các công đoạn: Ép keo cơi túi - 2 (Máy 2), Lựa số + vss5c đecup thân sau - 2 (Máy 2), Lựa số + vs4c đáy thân sau+ canh sọc - 2 (Máy 2), Ép keo paget - 5 (Máy 5), Vs3c xq túi đồng hồ - 2 (Máy 2), Bấm góc vs3c đáy tt - 2 (Máy 2), Chạy thun ống quần x2 + cắt + đo quần - 2 (Máy 2), Vs4c quần lót vào quần - 2 (Máy 2), Cắt chỉ + gọt lươc gà túi sau - 0 (Máy 0)
# Công nhân Trần Thị Oanh làm các công đoạn: Đo cắt pat túi thân sau - 0 (Máy 0), Gọt lộn dây treo túi sau + lộn - 0 (Máy 0), Vs3c bao túi thân sau + lộn - 2 (Máy 2), Lựa số + vs4c đáy thân sau+ canh sọc - 2 (Máy 2), Lược miệng túi thân sau - 1 (Máy 1), Vs3c paget tròn - 2 (Máy 2), Gỡ chỉ lược - 0 (Máy 0), Lấy dấu may nhãn lưng - 1 (Máy 1), Mí đáy thân trước - 1 (Máy 1), Lấy dấu lưng thùa khuyu - 0 (Máy 0)
# Công nhân Nguyễn Thị Gấm làm các công đoạn: Diễu kan sai đánh bông sườn thân x2 - 4 (Máy 4), Chạy kansai lưng - 4 (Máy 4)
# Công nhân Phan Thị Thu Hoài làm các công đoạn: Lấy dấu cắt gai xù túi sau + gọt góc - 0 (Máy 0), Nối dây pat túi thân sau - 1 (Máy 1), Diễu 6 ly bao túi thân sau + lộn - 1 (Máy 1), Bọ túi hông x4 - 3 (Máy 3), Bọ paget tròn x2 - 3 (Máy 3), Gắn nhãn tp - 1 (Máy 1), Bọ lưng + so dây - 3 (Máy 3), Thắt nơ dây luồn quần - 0 (Máy 0), Cắt chỉ + gọt lươc gà túi sau - 0 (Máy 0), Uỉ bao túi hông x2+túi sau - 0 (Máy 0)
# Công nhân Nguyễn Thị Thu làm các công đoạn: Lược miệng túi thân sau - 1 (Máy 1), Lược bao túi vào thân x2 - 1 (Máy 1), Quay paget tròn + đặt rập + ld - 1 (Máy 1), Bọ paget tròn x2 - 3 (Máy 3), Vs4c sườn thân x2 - 0 (Máy 0), Lộn quần ( trái sang phải ) - 1 (Máy 1), Gấp đôi bấm dấu nhãn tp - 0 (Máy 0), Bọ lưng + so dây - 3 (Máy 3), Bọ đáy - 3 (Máy 3), Xỏ dây luồn lưng + so dây - 0 (Máy 0)
# Công nhân Nguyễn Thị Hài làm các công đoạn: Lựa số + vss5c đecup thân sau - 2 (Máy 2), Kansai đáy thân sau - 4 (Máy 4), Diễu kan sai đánh bông sườn thân x2 - 4 (Máy 4), Chạy kansai lưng - 4 (Máy 4), Vệ sinh công nghiệp - 0 (Máy 0), Lộn quần ( trái sang phải ) - 0 (Máy 0)
# Công nhân Nguyễn Thị Hồng không có công việc.

# %%
# Lấy cá thể tốt nhất từ quần thể tốt nhất
best_individual = max(best_population, key=fitness_multi_with_machine_limit)

# Gán lời giải tốt nhất (nhiều công nhân trên mỗi công đoạn) vào bảng kết quả
dt['Công Nhân Mới (Nhiều)'] = [", ".join(worker_list) for worker_list in best_individual]

# Hiển thị kết quả cuối cùng
dt[['TÊN CÔNG ĐOẠN', 'Công Nhân Mới (Nhiều)']]
# Out:
#                                TÊN CÔNG ĐOẠN  \
# 0                       Xã phà thun lưng - 0
# 1   Lấy dấu cắt gai xù túi sau + gọt góc - 0
# 2                Đo cắt pat túi thân sau - 0
# 3       Đo cắt dây treo gắn túi thân sau - 0
# 4               Nối dây pat túi thân sau - 1
# ..                                       ...
# 80                   Vệ sinh công nghiệp - 0
# 81           Lộn quần ( trái sang phải ) - 0
# 82                     Mí đáy thân trước - 1
# 83               Lấy dấu lưng thùa khuyu - 0
# 84            Uỉ bao túi hông x2+túi sau - 0
#
#                                 Công Nhân Mới (Nhiều)
# 0               Hoàng Thị Mỹ Yến, Nguyễn Thị Ngọc Lan
# 1                    Ngô Khắc Hiển, Phan Thị Thu Hoài
# 2                  Trần Thị Oanh, Nguyễn Thị Mỹ Nhung
# 3                                     Nguyễn Thị Thúy
# 4                 Lê Thị Như Quỳnh, Phan Thị Thu Hoài
# ..                                                ...
# 80                       Hoàng Thị Nở, Nguyễn Thị Hài
# 81  Nguyễn Thị Hài, Ngô Khắc Hiển, Nguyễn Thị Ngọc...
# 82                                      Trần Thị Oanh
# 83                     Trần Thị Oanh, Nguyễn Thị Thúy
# 84                   Ngô Khắc Hiển, Phan Thị Thu Hoài
#
# [85 rows x 2 columns]

# %%
def display_task_allocation_with_time(individual):
    detailed_task_allocation = {worker: [] for worker in workers}

    for task_idx, worker_list in enumerate(individual):
        task_time = dt['TGLT'][task_idx]
        n_workers = len(worker_list)

        # Tính thời gian chia đều lý thuyết cho mỗi công nhân
        theoretical_time_per_worker = task_time / n_workers

        # Điều chỉnh thời gian cho từng công nhân theo độ thông thạo của họ
        for worker in worker_list:
            proficiency = proficiency_levels[worker]
            worker_time = theoretical_time_per_worker / proficiency  # Điều chỉnh thời gian theo độ thông thạo
            detailed_task_allocation[worker].append(f"Công đoạn {dt['TÊN CÔNG ĐOẠN'].iloc[task_idx]}: {worker_time:.2f} giây")

    return detailed_task_allocation


# Chọn cá thể tốt nhất (cá thể có độ lệch chuẩn nhỏ nhất)
task_allocation_with_time = display_task_allocation_with_time(best_individual)

# Hiển thị chi tiết công việc cho mỗi công nhân
worker_task_summary = []
worker_time = []

for worker, tasks in task_allocation_with_time.items():
    # Tính tổng thời gian cho mỗi công nhân
    total_time = sum(float(task.split(": ")[1].split()[0]) for task in tasks)
    # Chi tiết các công đoạn
    task_details = " + ".join(tasks)
    worker_task_summary.append({
        'Công Nhân': worker,
        'Chi Tiết Công Việc': task_details,
        'Tổng Thời Gian': total_time
    })
    worker_time.append({
        'Công Nhân': worker,
        'Tổng Thời Gian': total_time
    })

# Chuyển thành DataFrame để hiển thị
worker_task_summary_df = pd.DataFrame(worker_task_summary)

# Hiển thị kết quả chi tiết cho mỗi công nhân
worker_task_summary_df
def display_task_allocation_with_time(individual):
    detailed_task_allocation = {worker: [] for worker in workers}

    for task_idx, worker_list in enumerate(individual):
        task_time = dt['TGLT'][task_idx]
        n_workers = len(worker_list)

        # Tính thời gian chia đều lý thuyết cho mỗi công nhân
        theoretical_time_per_worker = task_time / n_workers

        # Điều chỉnh thời gian cho từng công nhân theo độ thông thạo của họ
        for worker in worker_list:
            proficiency = proficiency_levels[worker]
            worker_time = theoretical_time_per_worker / proficiency  # Điều chỉnh thời gian theo độ thông thạo
            detailed_task_allocation[worker].append(f"Công đoạn {dt['TÊN CÔNG ĐOẠN'].iloc[task_idx]}: {worker_time:.2f} giây")

    return detailed_task_allocation


# Chọn cá thể tốt nhất (cá thể có độ lệch chuẩn nhỏ nhất)
task_allocation_with_time = display_task_allocation_with_time(best_individual)

# Hiển thị chi tiết công việc cho mỗi công nhân
worker_task_summary = []
worker_time = []

for worker, tasks in task_allocation_with_time.items():
    # Tính tổng thời gian cho mỗi công nhân
    total_time = sum(float(task.split(": ")[1].split()[0]) for task in tasks)
    # Chi tiết các công đoạn
    task_details = " + ".join(tasks)
    worker_task_summary.append({
        'Công Nhân': worker,
        'Chi Tiết Công Việc': task_details,
        'Tổng Thời Gian': total_time
    })
    worker_time.append({
        'Công Nhân': worker,
        'Tổng Thời Gian': total_time
    })

# Chuyển thành DataFrame để hiển thị
worker_task_summary_df = pd.DataFrame(worker_task_summary)

# Hiển thị kết quả chi tiết cho mỗi công nhân
worker_task_summary_df
# Out:
#               Công Nhân                                 Chi Tiết Công Việc  \
# 0    Lê Thị Phương Thảo
# 1      Hoàng Thị Mỹ Yến  Công đoạn Xã phà thun lưng - 0: 1.29 giây + Cô...
# 2        Trần Thị Tuyền
# 3         Ngô Khắc Hiển  Công đoạn Lấy dấu cắt gai xù túi sau + gọt góc...
# 4           Hồ Thị Diệp  Công đoạn Kẹp mí đáp túi + bỏ dây treo thân sa...
# 5   Nguyễn Thị Mỹ Nhung  Công đoạn Đo cắt pat túi thân sau - 0: 0.86 gi...
# 6          Thái Thị Nga  Công đoạn Kẹp mí đáp túi + bỏ dây treo thân sa...
# 7          Trần Thị Cúc  Công đoạn Bỏ rập đh cơi túi ( xù, pat, lược tp...
# 8       Lê Thị Thanh Hà  Công đoạn Vs3c xq túi đồng hồ - 2: 4.89 giây +...
# 9       Nguyễn Thị Thúy  Công đoạn Đo cắt dây treo gắn túi thân sau - 0...
# 10     Trần Thị Cẩm Rin
# 11         Hoàng Thị Nở  Công đoạn Ép keo cơi túi - 2: 1.44 giây + Công...
# 12     Lê Thị Như Quỳnh  Công đoạn Nối dây pat túi thân sau - 1: 4.31 g...
# 13      Trần Thị Thương  Công đoạn Bọ túi thân sau x2 - 3: 8.62 giây + ...
# 14          Đinh Thị Mi  Công đoạn Bấm góc túi thân sau + chốt 2 đầu cơ...
# 15  Nguyễn Thị Ngọc Lan  Công đoạn Xã phà thun lưng - 0: 1.29 giây + Cô...
# 16     Bùi Thị Hồng Vân  Công đoạn Ép keo cơi túi - 2: 1.67 giây + Công...
# 17        Trần Thị Oanh  Công đoạn Đo cắt pat túi thân sau - 0: 0.86 gi...
# 18       Nguyễn Thị Gấm  Công đoạn Diễu kan sai đánh bông sườn thân x2 ...
# 19    Phan Thị Thu Hoài  Công đoạn Lấy dấu cắt gai xù túi sau + gọt góc...
# 20       Nguyễn Thị Thu  Công đoạn Lược miệng túi thân sau - 1: 8.19 gi...
# 21       Nguyễn Thị Hài  Công đoạn Lựa số + vss5c đecup thân sau - 2: 4...
# 22      Nguyễn Thị Hồng
#
#     Tổng Thời Gian
# 0             0.00
# 1           118.12
# 2             0.00
# 3           124.84
# 4           110.49
# 5           116.09
# 6           115.51
# 7           125.00
# 8           122.13
# 9           122.56
# 10            0.00
# 11          108.48
# 12          115.51
# 13          119.69
# 14          121.12
# 15           54.74
# 16          124.67
# 17          116.09
# 18           66.29
# 19          110.78
# 20          109.65
# 21          120.12
# 22            0.00

# %%
def display_stage_times(individual):
    stage_times = []

    for task_idx, worker_list in enumerate(individual):
        task_time = dt['TGLT'][task_idx]
        n_workers = len(worker_list)

        # Tính thời gian lý thuyết chia đều cho mỗi công nhân
        theoretical_time_per_worker = task_time / n_workers

        # Tính thời gian điều chỉnh cho mỗi công nhân dựa trên độ thông thạo
        worker_times = []
        for worker in worker_list:
            proficiency = proficiency_levels[worker]
            worker_time = theoretical_time_per_worker / proficiency  # Điều chỉnh thời gian theo độ thông thạo
            worker_times.append(worker_time)

        # Nếu có 1 công nhân, giữ nguyên thời gian
        if n_workers == 1:
            total_time_for_task = worker_times[0]
        # Nếu có 2 công nhân, lấy người nhanh nhất và nhân đôi thời gian
        elif n_workers == 2:
            total_time_for_task = min(worker_times) * 2
        # Nếu có 3 công nhân, lấy người nhanh nhất và nhân ba thời gian
        elif n_workers == 3:
            total_time_for_task = min(worker_times) * 3

        # Lưu trữ thời gian cho từng công đoạn
        stage_times.append({
            'Công Đoạn': dt['TÊN CÔNG ĐOẠN'].iloc[task_idx],
            'Tổng Thời Gian': total_time_for_task
        })

    return stage_times

# Sử dụng hàm display_stage_times để hiển thị thời gian của từng công đoạn
stage_times_summary = display_stage_times(best_individual)

# Chuyển thành DataFrame để hiển thị
stage_times_df = pd.DataFrame(stage_times_summary)

# Hiển thị kết quả
stage_times_df
# Out:
#                                    Công Đoạn  Tổng Thời Gian
# 0                       Xã phà thun lưng - 0        2.586207
# 1   Lấy dấu cắt gai xù túi sau + gọt góc - 0        3.448276
# 2                Đo cắt pat túi thân sau - 0        1.724138
# 3       Đo cắt dây treo gắn túi thân sau - 0        4.310345
# 4               Nối dây pat túi thân sau - 1        8.620690
# ..                                       ...             ...
# 80                   Vệ sinh công nghiệp - 0       26.724138
# 81           Lộn quần ( trái sang phải ) - 0        4.310345
# 82                     Mí đáy thân trước - 1       12.931034
# 83               Lấy dấu lưng thùa khuyu - 0        7.758621
# 84            Uỉ bao túi hông x2+túi sau - 0       25.862069
#
# [85 rows x 2 columns]

# %%
worker_time_df =  pd.DataFrame(worker_time)
worker_time_df
# Out:
#               Công Nhân  Tổng Thời Gian
# 0    Lê Thị Phương Thảo            0.00
# 1      Hoàng Thị Mỹ Yến          118.12
# 2        Trần Thị Tuyền            0.00
# 3         Ngô Khắc Hiển          124.84
# 4           Hồ Thị Diệp          110.49
# 5   Nguyễn Thị Mỹ Nhung          116.09
# 6          Thái Thị Nga          115.51
# 7          Trần Thị Cúc          125.00
# 8       Lê Thị Thanh Hà          122.13
# 9       Nguyễn Thị Thúy          122.56
# 10     Trần Thị Cẩm Rin            0.00
# 11         Hoàng Thị Nở          108.48
# 12     Lê Thị Như Quỳnh          115.51
# 13      Trần Thị Thương          119.69
# 14          Đinh Thị Mi          121.12
# 15  Nguyễn Thị Ngọc Lan           54.74
# 16     Bùi Thị Hồng Vân          124.67
# 17        Trần Thị Oanh          116.09
# 18       Nguyễn Thị Gấm           66.29
# 19    Phan Thị Thu Hoài          110.78
# 20       Nguyễn Thị Thu          109.65
# 21       Nguyễn Thị Hài          120.12
# 22      Nguyễn Thị Hồng            0.00

# %%
#tổng thời gian từng công đoạn lớn
#lấy dấu
total_1  =sum(stage['Tổng Thời Gian'] for stage in stage_times_summary[0:4])
#Thân sau
total_2  =sum(stage['Tổng Thời Gian'] for stage in stage_times_summary[4:27])
#Thân trước
total_3  =sum(stage['Tổng Thời Gian'] for stage in stage_times_summary[27:50])
#Lưng
total_4  =sum(stage['Tổng Thời Gian'] for stage in stage_times_summary[50:53])
#quần lót
total_5  =sum(stage['Tổng Thời Gian'] for stage in stage_times_summary[53:57])
#hoàn thành
total_6  =sum(stage['Tổng Thời Gian'] for stage in stage_times_summary[57:85])

# %%
# tổng số sản phẩm trong 1 ngày
re_stage_time = total_1+max(max(total_2,total_3)+total_4,total_5)+total_6
total_product = (28800-re_stage_time)/worker_time_df['Tổng Thời Gian'].max()+1
total_product
# Out:
# 219.58904911180773

# %%
lamda*alpha*total_product/f_0+(1-alpha)*g_0/total_salary
# Out:
# 1.0270586795248229
