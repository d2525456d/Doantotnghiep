# %%
import numpy as np
import pandas as pd
import random

# %%
dt = pd.read_csv('data.csv')
dt
# Out:
#     STT                         TÊN CÔNG ĐOẠN THIẾT BỊ  TG  HỆ SỐ  TGLT  \
# 0     1                      Xã phà thun lưng       ủi   3   1.00     3
# 1     2  Lấy dấu cắt gai xù túi sau + gọt góc       tc   4   1.00     4
# 2     3               Đo cắt pat túi thân sau       tc   2   1.00     2
# 3     4      Đo cắt dây treo gắn túi thân sau       tc   5   1.00     5
# 4     6              Nối dây pat túi thân sau       1k   8   1.16    10
# ..  ...                                   ...      ...  ..    ...   ...
# 80   89                   Vệ sinh công nghiệp       tc  31   1.00    31
# 81   90           Lộn quần ( trái sang phải )       TC   5   1.00     5
# 82   91                     Mí đáy thân trước       1K  13   1.16    15
# 83   92               Lấy dấu lưng thùa khuyu       TC   9   1.00     9
# 84   93            Uỉ bao túi hông x2+túi sau       ủi  30   1.00    30
#
#     ĐƠN GIÁ  Độ khó                         Công Nhân
# 0        15       2                      Trần Thị Cúc
# 1        20       1                      Trần Thị Cúc
# 2        10       1                      Trần Thị Cúc
# 3        24       1                      Trần Thị Cúc
# 4        51       1                      Trần Thị Cúc
# ..      ...     ...                               ...
# 80      162       1  Lê Thị Thanh Hà + Nguyễn Thị Hài
# 81       25       3                  Lê Thị Như Quỳnh
# 82       80       2                   Lê Thị Thanh Hà
# 83       49       2                      Trần Thị Cúc
# 84      159       2                     Ngô Khắc Hiển
#
# [85 rows x 9 columns]

# %%
tasks_times = dt['TGLT'].dropna().tolist()

# %%
# Số thế hệ và xác suất đột biến
num_generations = 500
mutation_rate = 0.2
workers = [
    "Lê Thị Phương Thảo", "Hoàng Thị Mỹ Yến", "Trần Thị Tuyền", "Ngô Khắc Hiển",
    "Hồ Thị Diệp", "Nguyễn Thị Mỹ Nhung", "Thái Thị Nga",
    "Trần Thị Cúc", "Lê Thị Thanh Hà", "Nguyễn Thị Thúy", "Trần Thị Cẩm Rin",
    "Hoàng Thị Nở", "Lê Thị Như Quỳnh", "Trần Thị Thương", "Đinh Thị Mi",
    "Nguyễn Thị Ngọc Lan", "Bùi Thị Hồng Vân", "Trần Thị Oanh",
    "Nguyễn Thị Gấm", "Phan Thị Thu Hoài", "Nguyễn Thị Thu", "Nguyễn Thị Hài",
    "Nguyễn Thị Hồng"
]
num_workers = len(workers)

# %%
# Định nghĩa độ thành thạo của từng công nhân
proficiency_levels = {
    "Lê Thị Phương Thảo": 1.48,
    "Hoàng Thị Mỹ Yến": 1.16,
    "Trần Thị Tuyền": 1.48,
    "Ngô Khắc Hiển": 1.00,
    "Hồ Thị Diệp": 1.16,
    "Nguyễn Thị Mỹ Nhung": 1.16,
    "Thái Thị Nga": 1.16,
    "Trần Thị Cúc": 1.00,
    "Lê Thị Thanh Hà": 1.16,
    "Nguyễn Thị Thúy": 1.16,
    "Trần Thị Cẩm Rin": 1.32,
    "Hoàng Thị Nở": 1.16,
    "Lê Thị Như Quỳnh": 1.16,
    "Trần Thị Thương": 1.16,
    "Đinh Thị Mi": 1.16,
    "Nguyễn Thị Ngọc Lan": 1.16,
    "Bùi Thị Hồng Vân": 1.00,
    "Trần Thị Oanh": 1.16,
    "Nguyễn Thị Gấm": 1.32,
    "Phan Thị Thu Hoài": 1.16,
    "Nguyễn Thị Thu": 1.16,
    "Nguyễn Thị Hài": 1.16,
    "Nguyễn Thị Hồng": 1.48
}

# %%
# Khởi tạo quần thể
population_size = 1000

# %%
machines = [
    0, 0, 0, 0,
    1, 2, 1, 1, 0, 2, 7, 1, 7, 0, 1, 1, 2, 1, 2, 2, 1, 1, 1, 3, 2, 4, 1,
    5, 1, 1, 1, 1, 2, 7, 1, 1, 1, 1, 1, 2, 1, 1, 3, 2, 2, 7, 1, 1, 3, 7,
    6, 2, 0,
    0, 0, 2, 1,
    2, 4, 2, 4, 1, 1, 0, 1, 1, 1, 4, 0, 1, 1, 2, 0, 3, 0, 3, 1, 0, 0, 0, 0, 0, 1, 0, 0
]

# %%
# Thêm cột "Loại Máy" từ danh sách machines
dt['Loại Máy'] = machines

# Thay thế cột "TÊN CÔNG ĐOẠN" bằng chuỗi kết hợp "TÊN CÔNG ĐOẠN" và "Loại Máy"
dt['TÊN CÔNG ĐOẠN'] = dt['TÊN CÔNG ĐOẠN'] + ' - ' + dt['Loại Máy'].astype(str)

# Hiển thị DataFrame kết quả
dt
# Out:
#     STT                             TÊN CÔNG ĐOẠN THIẾT BỊ  TG  HỆ SỐ  TGLT  \
# 0     1                      Xã phà thun lưng - 0       ủi   3   1.00     3
# 1     2  Lấy dấu cắt gai xù túi sau + gọt góc - 0       tc   4   1.00     4
# 2     3               Đo cắt pat túi thân sau - 0       tc   2   1.00     2
# 3     4      Đo cắt dây treo gắn túi thân sau - 0       tc   5   1.00     5
# 4     6              Nối dây pat túi thân sau - 1       1k   8   1.16    10
# ..  ...                                       ...      ...  ..    ...   ...
# 80   89                   Vệ sinh công nghiệp - 0       tc  31   1.00    31
# 81   90           Lộn quần ( trái sang phải ) - 0       TC   5   1.00     5
# 82   91                     Mí đáy thân trước - 1       1K  13   1.16    15
# 83   92               Lấy dấu lưng thùa khuyu - 0       TC   9   1.00     9
# 84   93            Uỉ bao túi hông x2+túi sau - 0       ủi  30   1.00    30
#
#     ĐƠN GIÁ  Độ khó                         Công Nhân  Loại Máy
# 0        15       2                      Trần Thị Cúc         0
# 1        20       1                      Trần Thị Cúc         0
# 2        10       1                      Trần Thị Cúc         0
# 3        24       1                      Trần Thị Cúc         0
# 4        51       1                      Trần Thị Cúc         1
# ..      ...     ...                               ...       ...
# 80      162       1  Lê Thị Thanh Hà + Nguyễn Thị Hài         0
# 81       25       3                  Lê Thị Như Quỳnh         0
# 82       80       2                   Lê Thị Thanh Hà         1
# 83       49       2                      Trần Thị Cúc         0
# 84      159       2                     Ngô Khắc Hiển         0
#
# [85 rows x 10 columns]

# %%
# # Adjust fitness_multi to handle multiple workers properly with correct workload distribution
# def fitness_multi(individual):
#     workload = {worker: 0 for worker in workers}
#     for task_idx, worker_list in enumerate(individual):
#         task_time = dt['TGLT'].iloc[task_idx]
#         # Chia đều thời gian công đoạn cho các công nhân thực hiện công đoạn đó,
#         # và điều chỉnh thời gian dựa trên độ thành thạo
#         adjusted_time = task_time / max(proficiency_levels[worker] for worker in worker_list)
#         for worker in worker_list:
#             # Tính thời gian điều chỉnh cho mỗi công nhân và thêm vào workload của họ
#             workload[worker] += adjusted_time / len(worker_list)

#     # Tính độ lệch chuẩn của tổng khối lượng công việc của tất cả công nhân (càng nhỏ càng tốt)
#     workload_values = np.array(list(workload.values()))
#     return np.std(workload_values)
# def adjust_task_time_with_proficiency(individual):
#     worker_times = {worker: 0 for worker in workers}

#     for task_idx, worker_list in enumerate(individual):
#         task_time = dt['TGLT'][task_idx]
#         n_workers = len(worker_list)

#         # Thời gian lý thuyết chia đều cho mỗi công nhân
#         theoretical_time_per_worker = task_time / n_workers

#         # Tính thời gian thực tế cho mỗi công nhân dựa trên độ thông thạo
#         for worker in worker_list:
#             worker_proficiency = proficiency_levels[worker]
#             # Điều chỉnh thời gian thực tế dựa trên độ thông thạo của công nhân
#             worker_time = theoretical_time_per_worker * (1 / worker_proficiency)
#             worker_times[worker] += worker_time  # Lưu thời gian cho từng công nhân

#     return worker_times


# def display_stage_times(individual):
#     detailed_task_allocation = {worker: [] for worker in workers}

#     for task_idx, worker_list in enumerate(individual):
#         task_time = dt['TGLT'][task_idx]
#         n_workers = len(worker_list)

#         # Tính thời gian chia đều lý thuyết cho mỗi công nhân
#         theoretical_time_per_worker = task_time / n_workers

#         # Điều chỉnh thời gian cho từng công nhân theo độ thông thạo của họ
#         for worker in worker_list:
#             proficiency = proficiency_levels[worker]
#             worker_time = theoretical_time_per_worker / proficiency  # Điều chỉnh thời gian theo độ thông thạo
#             detailed_task_allocation[worker].append(f"Công đoạn {dt['TÊN CÔNG ĐOẠN'].iloc[task_idx]}: {worker_time:.2f} giây")
#     task_allocation_with_time = detailed_task_allocation
#     worker_time = []

#     for worker, tasks in task_allocation_with_time.items():
#         # Tính tổng thời gian cho mỗi công nhân
#         total_time = sum(float(task.split(": ")[1].split()[0]) for task in tasks)
#         # Chi tiết các công đoạn
#         task_details = " + ".join(tasks)

#         worker_time.append({
#             'Công Nhân': worker,
#             'Tổng Thời Gian': total_time
#         })
#     worker_time_df =  pd.DataFrame(worker_time)

#     stage_times = []

#     for task_idx, worker_list in enumerate(individual):
#         task_time = dt['TGLT'][task_idx]
#         n_workers = len(worker_list)

#         # Tính thời gian lý thuyết chia đều cho mỗi công nhân
#         theoretical_time_per_worker = task_time / n_workers

#         # Tính thời gian điều chỉnh cho mỗi công nhân dựa trên độ thông thạo
#         worker_times = []
#         for worker in worker_list:
#             proficiency = proficiency_levels[worker]
#             worker_time = theoretical_time_per_worker / proficiency  # Điều chỉnh thời gian theo độ thông thạo
#             worker_times.append(worker_time)

#         # Nếu có 1 công nhân, giữ nguyên thời gian
#         if n_workers == 1:
#             total_time_for_task = worker_times[0]
#         # Nếu có 2 công nhân, lấy người nhanh nhất và nhân đôi thời gian
#         elif n_workers == 2:
#             total_time_for_task = min(worker_times) * 2
#         # Nếu có 3 công nhân, lấy người nhanh nhất và nhân ba thời gian
#         elif n_workers == 3:
#             total_time_for_task = min(worker_times) * 3

#         # Lưu trữ thời gian cho từng công đoạn
#         stage_times.append(total_time_for_task)
#     #tổng thời gian từng công đoạn lớn
#     #lấy dấu
#     total_1  =sum(stage for stage in stage_times[0:4])
#     #Thân sau
#     total_2  =sum(stage for stage in stage_times[4:27])
#     #Thân trước
#     total_3  =sum(stage for stage in stage_times[27:50])
#     #Lưng
#     total_4  =sum(stage for stage in stage_times[50:53])
#     #quần lót
#     total_5  =sum(stage for stage in stage_times[53:57])
#     #hoàn thành
#     total_6  =sum(stage for stage in stage_times[57:85])
#     # tổng số sản phẩm trong 1 ngày
#     re_stage_time = total_1+max(max(total_2,total_3)+total_4,total_5)+total_6
#     total_product = (28800-re_stage_time)/worker_time_df['Tổng Thời Gian'].max()+1
#     total_product

#     return total_product

# Tính lại độ lệch chuẩn dựa trên thời gian điều chỉnh (nếu cần)

# def fitness_multi(individual):
#     worker_times = adjust_task_time_with_proficiency(individual)
#     return np.std(list(worker_times.values()))
# Hàm tính tổng tiền lương cho cá thể (phân công công nhân)
def calculate_total_salary(individual, proficiency_levels, dt):
    worker_salaries = {worker: 0 for worker in workers}

    for task_idx, worker_list in enumerate(individual):
        task_price = dt['ĐƠN GIÁ'][task_idx]
        num_workers = len(worker_list)
        price_per_worker = task_price / num_workers

        # Tính lương cho từng công nhân dựa trên năng lực
        for worker in worker_list:
            proficiency = proficiency_levels[worker]
            salary_for_task = price_per_worker * proficiency
            worker_salaries[worker] += salary_for_task

    # Tổng tiền lương cho tất cả công nhân trong cá thể này
    total_salary = sum(worker_salaries.values())
    return total_salary

# Khởi tạo quần thể ban đầu với nhiều công nhân cho mỗi công đoạn
def generate_population_multi():
    population = []

    for _ in range(population_size):
        individual = []
        worker_machine_assignment = {worker: set() for worker in workers}  # Theo dõi loại máy mà mỗi công nhân đã làm

        for task_idx in range(len(dt)):
            machine_type = machines[task_idx]  # Máy móc của công đoạn này
            available_workers = []

            # Chỉ chọn những công nhân có thể làm việc với loại máy này mà không vi phạm ràng buộc
            for worker in workers:
                machine_types_assigned = worker_machine_assignment[worker]
                if machine_type == 0:
                    # Nếu là máy loại 0, cho phép công nhân làm tối đa 3 loại máy
                    if len(machine_types_assigned) < 3 or machine_type in machine_types_assigned:
                        available_workers.append(worker)
                else:
                    # Nếu không phải máy loại 0, chỉ cho phép làm tối đa 2 loại máy
                    if len(machine_types_assigned) < 2 or machine_type in machine_types_assigned:
                        available_workers.append(worker)

            # Đảm bảo số lượng công nhân có thể chọn nằm trong giới hạn của available_workers
            n_selected_workers = min(len(available_workers), random.randint(1, 3))
            if n_selected_workers > 0:
                selected_workers = random.sample(available_workers, n_selected_workers)

                # Cập nhật loại máy mà các công nhân được gán làm
                for worker in selected_workers:
                    worker_machine_assignment[worker].add(machine_type)

                individual.append(selected_workers)
            else:
                # Nếu không có công nhân nào khả dụng, có thể thêm xử lý ngoại lệ
                individual.append([])  # Hoặc có thể xử lý khác nếu cần

        population.append(individual)

    return population


def selection_multi(population):
    product_scores = [(individual, fitness_multi_with_machine_limit(individual)) for individual in population]
    # Loại bỏ các cá thể có fitness là None (không hợp lệ)
    valid_population = [(ind, score) for ind, score in product_scores if score is not None]

    # Xếp theo lương, càng thấp càng tốt
    valid_population.sort(key=lambda x: x[1], reverse=False)

    # Trả về một nửa quần thể tốt nhất
    return [individual for individual, score in valid_population[:population_size // 2]]


# Giao phối (Crossover) với danh sách nhiều công nhân trên mỗi công đoạn
def crossover_multi(parent1, parent2):
    point = random.randint(1, len(dt) - 2)
    child1 = parent1[:point] + parent2[point:]
    child2 = parent2[:point] + parent1[point:]
    return child1, child2

# Đột biến (Mutation): thay đổi ngẫu nhiên danh sách công nhân cho một công đoạn
def mutate_multi(individual):
    if random.random() < mutation_rate:
        task_idx = random.randint(0, len(dt) - 1)
        # Chọn ngẫu nhiên từ 1 đến 3 công nhân cho công đoạn này
        individual[task_idx] = random.sample(workers, random.randint(1, 3))
    return individual
# Vòng lặp chính của giải thuật di truyền với nhiều công nhân trên mỗi công đoạn
# Điều chỉnh lại hàm trả về chỉ 2 giá trị để tránh lỗi "too many values to unpack"

# %%
def fitness_multi_with_machine_limit(individual):

    # Kiểm tra ràng buộc về công nhân cho mỗi công đoạn (ít nhất một công nhân)
    for task_idx, worker_list in enumerate(individual):
        if len(worker_list) == 0:  # Công đoạn không có công nhân
            return None  # Đánh dấu là không hợp lệ

    # Kiểm tra số loại máy mà mỗi công nhân làm việc
    worker_machine_types = {worker: set() for worker in workers}

    for task_idx, worker_list in enumerate(individual):
        machine_type = machines[task_idx]
        for worker in worker_list:
            worker_machine_types[worker].add(machine_type)

    # Ràng buộc số loại máy tối đa cho mỗi công nhân
    penalty = 0
    for worker, machine_types in worker_machine_types.items():
        if 0 in machine_types:
            if len(machine_types) > 3:  # Nếu có máy loại 0, tối đa là 3 loại máy
                penalty += 1  # Đánh dấu vi phạm
        else:
            if len(machine_types) > 2:  # Nếu không có máy loại 0, tối đa là 2 loại máy
                penalty += 1  # Đánh dấu vi phạm

    if penalty > 0:
        return None  # Cá thể vi phạm, không hợp lệ
    else:
        return calculate_total_salary(individual, proficiency_levels, dt)  #tính toán tổng tiền thấp nhất

# %%
# Vòng lặp chính của giải thuật di truyền
best_population = []
population = generate_population_multi()
min_best_wages = float('inf')  # Khởi tạo giá trị tiền lương thấp nhất

for generation in range(num_generations):
    # Lựa chọn các cá thể tốt nhất (không bị vi phạm)
    selected_population = selection_multi(population)

    # Giao phối và tạo thế hệ mới
    new_population = []
    while len(new_population) < population_size:
        parent1, parent2 = random.sample(selected_population, 2)
        child1, child2 = crossover_multi(parent1, parent2)
        mutated_child1 = mutate_multi(child1)
        mutated_child2 = mutate_multi(child2)

        # Kiểm tra xem các cá thể có thỏa mãn điều kiện ràng buộc không
        fitness_child1 = fitness_multi_with_machine_limit(mutated_child1)
        fitness_child2 = fitness_multi_with_machine_limit(mutated_child2)

        # Nếu cá thể thỏa mãn điều kiện ràng buộc, thêm vào quần thể mới
        if fitness_child1 is not None:
            new_population.append(mutated_child1)
        if fitness_child2 is not None:
            new_population.append(mutated_child2)

    # Cập nhật quần thể
    population = new_population[:population_size]  # Đảm bảo kích thước quần thể không vượt quá giới hạn

    # Lấy ra giải pháp có tổng chi phí thấp nhất trong thế hệ này
    best_individual = min(population, key=lambda ind: fitness_multi_with_machine_limit(ind) or float('inf'))
    best_wages = fitness_multi_with_machine_limit(best_individual)

    # Cập nhật nếu tìm được chi phí thấp hơn
    if best_wages and min_best_wages > best_wages:
        min_best_wages = best_wages
        best_population = population

    print(f"Thế hệ {generation + 1}: Lương thấp nhất = {min_best_wages:.4f}")
    print(f"Thế hệ {generation + 1}: Lương hiện tại = {best_wages:.4f}")

# Lấy cá thể tốt nhất từ quần thể tốt nhất
best_individual = min(best_population, key=lambda ind: fitness_multi_with_machine_limit(ind) or float('inf'))
# Out:
# Thế hệ 1: Lương thấp nhất = 14575.5867
# Thế hệ 1: Lương hiện tại = 14575.5867
# Thế hệ 2: Lương thấp nhất = 14575.5867
# Thế hệ 2: Lương hiện tại = 14580.7600
# Thế hệ 3: Lương thấp nhất = 14516.0667
# Thế hệ 3: Lương hiện tại = 14516.0667
# Thế hệ 4: Lương thấp nhất = 14344.0133
# Thế hệ 4: Lương hiện tại = 14344.0133
# Thế hệ 5: Lương thấp nhất = 14343.9333
# Thế hệ 5: Lương hiện tại = 14343.9333
# Thế hệ 6: Lương thấp nhất = 14328.6000
# Thế hệ 6: Lương hiện tại = 14328.6000
# Thế hệ 7: Lương thấp nhất = 14328.6000
# Thế hệ 7: Lương hiện tại = 14349.2667
# Thế hệ 8: Lương thấp nhất = 14328.6000
# Thế hệ 8: Lương hiện tại = 14338.0133
# Thế hệ 9: Lương thấp nhất = 14312.3067
# Thế hệ 9: Lương hiện tại = 14312.3067
# Thế hệ 10: Lương thấp nhất = 14297.3467
# Thế hệ 10: Lương hiện tại = 14297.3467
# Thế hệ 11: Lương thấp nhất = 14288.0667
# Thế hệ 11: Lương hiện tại = 14288.0667
# Thế hệ 12: Lương thấp nhất = 14270.6533
# Thế hệ 12: Lương hiện tại = 14270.6533
# Thế hệ 13: Lương thấp nhất = 14252.5200
# Thế hệ 13: Lương hiện tại = 14252.5200
# Thế hệ 14: Lương thấp nhất = 14252.5200
# Thế hệ 14: Lương hiện tại = 14281.5867
# Thế hệ 15: Lương thấp nhất = 14200.5467
# Thế hệ 15: Lương hiện tại = 14200.5467
# Thế hệ 16: Lương thấp nhất = 14200.5467
# Thế hệ 16: Lương hiện tại = 14227.7733
# Thế hệ 17: Lương thấp nhất = 14200.5467
# Thế hệ 17: Lương hiện tại = 14223.9600
# Thế hệ 18: Lương thấp nhất = 14200.5467
# Thế hệ 18: Lương hiện tại = 14220.2533
# Thế hệ 19: Lương thấp nhất = 14200.5467
# Thế hệ 19: Lương hiện tại = 14203.2667
# Thế hệ 20: Lương thấp nhất = 14187.0533
# Thế hệ 20: Lương hiện tại = 14187.0533
# Thế hệ 21: Lương thấp nhất = 14175.8533
# Thế hệ 21: Lương hiện tại = 14175.8533
# Thế hệ 22: Lương thấp nhất = 14153.4000
# Thế hệ 22: Lương hiện tại = 14153.4000
# Thế hệ 23: Lương thấp nhất = 14122.0400
# Thế hệ 23: Lương hiện tại = 14122.0400
# Thế hệ 24: Lương thấp nhất = 14100.0933
# Thế hệ 24: Lương hiện tại = 14100.0933
# Thế hệ 25: Lương thấp nhất = 14065.6133
# Thế hệ 25: Lương hiện tại = 14065.6133
# Thế hệ 26: Lương thấp nhất = 14065.6133
# Thế hệ 26: Lương hiện tại = 14073.5600
# Thế hệ 27: Lương thấp nhất = 14044.8667
# Thế hệ 27: Lương hiện tại = 14044.8667
# Thế hệ 28: Lương thấp nhất = 14039.1867
# Thế hệ 28: Lương hiện tại = 14039.1867
# Thế hệ 29: Lương thấp nhất = 14008.2000
# Thế hệ 29: Lương hiện tại = 14008.2000
# Thế hệ 30: Lương thấp nhất = 13986.0400
# Thế hệ 30: Lương hiện tại = 13986.0400
# Thế hệ 31: Lương thấp nhất = 13952.2533
# Thế hệ 31: Lương hiện tại = 13952.2533
# Thế hệ 32: Lương thấp nhất = 13928.6800
# Thế hệ 32: Lương hiện tại = 13928.6800
# Thế hệ 33: Lương thấp nhất = 13918.6000
# Thế hệ 33: Lương hiện tại = 13918.6000
# Thế hệ 34: Lương thấp nhất = 13895.6933
# Thế hệ 34: Lương hiện tại = 13895.6933
# Thế hệ 35: Lương thấp nhất = 13885.2667
# Thế hệ 35: Lương hiện tại = 13885.2667
# Thế hệ 36: Lương thấp nhất = 13877.2667
# Thế hệ 36: Lương hiện tại = 13877.2667
# Thế hệ 37: Lương thấp nhất = 13861.8267
# Thế hệ 37: Lương hiện tại = 13861.8267
# Thế hệ 38: Lương thấp nhất = 13830.7333
# Thế hệ 38: Lương hiện tại = 13830.7333
# Thế hệ 39: Lương thấp nhất = 13807.6400
# Thế hệ 39: Lương hiện tại = 13807.6400
# Thế hệ 40: Lương thấp nhất = 13793.9600
# Thế hệ 40: Lương hiện tại = 13793.9600
# Thế hệ 41: Lương thấp nhất = 13789.6133
# Thế hệ 41: Lương hiện tại = 13789.6133
# Thế hệ 42: Lương thấp nhất = 13765.8267
# Thế hệ 42: Lương hiện tại = 13765.8267
# Thế hệ 43: Lương thấp nhất = 13759.2133
# Thế hệ 43: Lương hiện tại = 13759.2133
# Thế hệ 44: Lương thấp nhất = 13742.4400
# Thế hệ 44: Lương hiện tại = 13742.4400
# Thế hệ 45: Lương thấp nhất = 13709.0533
# Thế hệ 45: Lương hiện tại = 13709.0533
# Thế hệ 46: Lương thấp nhất = 13689.5333
# Thế hệ 46: Lương hiện tại = 13689.5333
# Thế hệ 47: Lương thấp nhất = 13667.3733
# Thế hệ 47: Lương hiện tại = 13667.3733
# Thế hệ 48: Lương thấp nhất = 13651.7733
# Thế hệ 48: Lương hiện tại = 13651.7733
# Thế hệ 49: Lương thấp nhất = 13621.8800
# Thế hệ 49: Lương hiện tại = 13621.8800
# Thế hệ 50: Lương thấp nhất = 13608.1200
# Thế hệ 50: Lương hiện tại = 13608.1200
# Thế hệ 51: Lương thấp nhất = 13589.7733
# Thế hệ 51: Lương hiện tại = 13589.7733
# Thế hệ 52: Lương thấp nhất = 13566.1733
# Thế hệ 52: Lương hiện tại = 13566.1733
# Thế hệ 53: Lương thấp nhất = 13566.1733
# Thế hệ 53: Lương hiện tại = 13568.8933
# Thế hệ 54: Lương thấp nhất = 13559.0267
# Thế hệ 54: Lương hiện tại = 13559.0267
# Thế hệ 55: Lương thấp nhất = 13540.9733
# Thế hệ 55: Lương hiện tại = 13540.9733
# Thế hệ 56: Lương thấp nhất = 13521.3467
# Thế hệ 56: Lương hiện tại = 13521.3467
# Thế hệ 57: Lương thấp nhất = 13509.5333
# Thế hệ 57: Lương hiện tại = 13509.5333
# Thế hệ 58: Lương thấp nhất = 13501.8533
# Thế hệ 58: Lương hiện tại = 13501.8533
# Thế hệ 59: Lương thấp nhất = 13501.8533
# Thế hệ 59: Lương hiện tại = 13506.7600
# Thế hệ 60: Lương thấp nhất = 13492.6800
# Thế hệ 60: Lương hiện tại = 13492.6800
# Thế hệ 61: Lương thấp nhất = 13483.5600
# Thế hệ 61: Lương hiện tại = 13483.5600
# Thế hệ 62: Lương thấp nhất = 13460.8933
# Thế hệ 62: Lương hiện tại = 13460.8933
# Thế hệ 63: Lương thấp nhất = 13460.8933
# Thế hệ 63: Lương hiện tại = 13460.8933
# Thế hệ 64: Lương thấp nhất = 13459.2400
# Thế hệ 64: Lương hiện tại = 13459.2400
# Thế hệ 65: Lương thấp nhất = 13446.7067
# Thế hệ 65: Lương hiện tại = 13446.7067
# Thế hệ 66: Lương thấp nhất = 13435.0267
# Thế hệ 66: Lương hiện tại = 13435.0267
# Thế hệ 67: Lương thấp nhất = 13424.0400
# Thế hệ 67: Lương hiện tại = 13424.0400
# Thế hệ 68: Lương thấp nhất = 13395.0000
# Thế hệ 68: Lương hiện tại = 13395.0000
# Thế hệ 69: Lương thấp nhất = 13395.0000
# Thế hệ 69: Lương hiện tại = 13395.0000
# Thế hệ 70: Lương thấp nhất = 13385.7467
# Thế hệ 70: Lương hiện tại = 13385.7467
# Thế hệ 71: Lương thấp nhất = 13356.8667
# Thế hệ 71: Lương hiện tại = 13356.8667
# Thế hệ 72: Lương thấp nhất = 13337.6133
# Thế hệ 72: Lương hiện tại = 13337.6133
# Thế hệ 73: Lương thấp nhất = 13337.6133
# Thế hệ 73: Lương hiện tại = 13337.6133
# Thế hệ 74: Lương thấp nhất = 13336.9733
# Thế hệ 74: Lương hiện tại = 13336.9733
# Thế hệ 75: Lương thấp nhất = 13321.8533
# Thế hệ 75: Lương hiện tại = 13321.8533
# Thế hệ 76: Lương thấp nhất = 13313.7733
# Thế hệ 76: Lương hiện tại = 13313.7733
# Thế hệ 77: Lương thấp nhất = 13296.6267
# Thế hệ 77: Lương hiện tại = 13296.6267
# Thế hệ 78: Lương thấp nhất = 13279.4267
# Thế hệ 78: Lương hiện tại = 13279.4267
# Thế hệ 79: Lương thấp nhất = 13279.4267
# Thế hệ 79: Lương hiện tại = 13279.4267
# Thế hệ 80: Lương thấp nhất = 13274.0667
# Thế hệ 80: Lương hiện tại = 13274.0667
# Thế hệ 81: Lương thấp nhất = 13271.5333
# Thế hệ 81: Lương hiện tại = 13271.5333
# Thế hệ 82: Lương thấp nhất = 13257.4267
# Thế hệ 82: Lương hiện tại = 13257.4267
# Thế hệ 83: Lương thấp nhất = 13252.4400
# Thế hệ 83: Lương hiện tại = 13252.4400
# Thế hệ 84: Lương thấp nhất = 13252.4400
# Thế hệ 84: Lương hiện tại = 13252.4400
# Thế hệ 85: Lương thấp nhất = 13233.9333
# Thế hệ 85: Lương hiện tại = 13233.9333
# Thế hệ 86: Lương thấp nhất = 13215.7200
# Thế hệ 86: Lương hiện tại = 13215.7200
# Thế hệ 87: Lương thấp nhất = 13208.0933
# Thế hệ 87: Lương hiện tại = 13208.0933
# Thế hệ 88: Lương thấp nhất = 13208.0933
# Thế hệ 88: Lương hiện tại = 13209.9867
# Thế hệ 89: Lương thấp nhất = 13190.1467
# Thế hệ 89: Lương hiện tại = 13190.1467
# Thế hệ 90: Lương thấp nhất = 13190.1467
# Thế hệ 90: Lương hiện tại = 13192.8667
# Thế hệ 91: Lương thấp nhất = 13189.8000
# Thế hệ 91: Lương hiện tại = 13189.8000
# Thế hệ 92: Lương thấp nhất = 13173.8267
# Thế hệ 92: Lương hiện tại = 13173.8267
# Thế hệ 93: Lương thấp nhất = 13162.9467
# Thế hệ 93: Lương hiện tại = 13162.9467
# Thế hệ 94: Lương thấp nhất = 13158.9467
# Thế hệ 94: Lương hiện tại = 13158.9467
# Thế hệ 95: Lương thấp nhất = 13148.3867
# Thế hệ 95: Lương hiện tại = 13148.3867
# Thế hệ 96: Lương thấp nhất = 13132.0667
# Thế hệ 96: Lương hiện tại = 13132.0667
# Thế hệ 97: Lương thấp nhất = 13128.6800
# Thế hệ 97: Lương hiện tại = 13128.6800
# Thế hệ 98: Lương thấp nhất = 13121.6667
# Thế hệ 98: Lương hiện tại = 13121.6667
# Thế hệ 99: Lương thấp nhất = 13121.6667
# Thế hệ 99: Lương hiện tại = 13121.6667
# Thế hệ 100: Lương thấp nhất = 13117.8800
# Thế hệ 100: Lương hiện tại = 13117.8800
# Thế hệ 101: Lương thấp nhất = 13110.2000
# Thế hệ 101: Lương hiện tại = 13110.2000
# Thế hệ 102: Lương thấp nhất = 13101.1067
# Thế hệ 102: Lương hiện tại = 13101.1067
# Thế hệ 103: Lương thấp nhất = 13092.5467
# Thế hệ 103: Lương hiện tại = 13092.5467
# Thế hệ 104: Lương thấp nhất = 13083.2667
# Thế hệ 104: Lương hiện tại = 13083.2667
# Thế hệ 105: Lương thấp nhất = 13075.2667
# Thế hệ 105: Lương hiện tại = 13075.2667
# Thế hệ 106: Lương thấp nhất = 13075.2667
# Thế hệ 106: Lương hiện tại = 13077.9067
# Thế hệ 107: Lương thấp nhất = 13067.1867
# Thế hệ 107: Lương hiện tại = 13067.1867
# Thế hệ 108: Lương thấp nhất = 13067.1867
# Thế hệ 108: Lương hiện tại = 13067.1867
# Thế hệ 109: Lương thấp nhất = 13062.3600
# Thế hệ 109: Lương hiện tại = 13062.3600
# Thế hệ 110: Lương thấp nhất = 13059.6133
# Thế hệ 110: Lương hiện tại = 13059.6133
# Thế hệ 111: Lương thấp nhất = 13051.5333
# Thế hệ 111: Lương hiện tại = 13051.5333
# Thế hệ 112: Lương thấp nhất = 13044.2533
# Thế hệ 112: Lương hiện tại = 13044.2533
# Thế hệ 113: Lương thấp nhất = 13038.2533
# Thế hệ 113: Lương hiện tại = 13038.2533
# Thế hệ 114: Lương thấp nhất = 13036.8667
# Thế hệ 114: Lương hiện tại = 13036.8667
# Thế hệ 115: Lương thấp nhất = 13021.9333
# Thế hệ 115: Lương hiện tại = 13021.9333
# Thế hệ 116: Lương thấp nhất = 13017.0267
# Thế hệ 116: Lương hiện tại = 13017.0267
# Thế hệ 117: Lương thấp nhất = 13017.0267
# Thế hệ 117: Lương hiện tại = 13017.1333
# Thế hệ 118: Lương thấp nhất = 12996.8400
# Thế hệ 118: Lương hiện tại = 12996.8400
# Thế hệ 119: Lương thấp nhất = 12993.7200
# Thế hệ 119: Lương hiện tại = 12993.7200
# Thế hệ 120: Lương thấp nhất = 12992.7600
# Thế hệ 120: Lương hiện tại = 12992.7600
# Thế hệ 121: Lương thấp nhất = 12991.3200
# Thế hệ 121: Lương hiện tại = 12991.3200
# Thế hệ 122: Lương thấp nhất = 12980.7067
# Thế hệ 122: Lương hiện tại = 12980.7067
# Thế hệ 123: Lương thấp nhất = 12978.9467
# Thế hệ 123: Lương hiện tại = 12978.9467
# Thế hệ 124: Lương thấp nhất = 12973.2667
# Thế hệ 124: Lương hiện tại = 12973.2667
# Thế hệ 125: Lương thấp nhất = 12956.0667
# Thế hệ 125: Lương hiện tại = 12956.0667
# Thế hệ 126: Lương thấp nhất = 12951.2667
# Thế hệ 126: Lương hiện tại = 12951.2667
# Thế hệ 127: Lương thấp nhất = 12949.6667
# Thế hệ 127: Lương hiện tại = 12949.6667
# Thế hệ 128: Lương thấp nhất = 12949.6667
# Thế hệ 128: Lương hiện tại = 12951.8000
# Thế hệ 129: Lương thấp nhất = 12949.4267
# Thế hệ 129: Lương hiện tại = 12949.4267
# Thế hệ 130: Lương thấp nhất = 12944.5200
# Thế hệ 130: Lương hiện tại = 12944.5200
# Thế hệ 131: Lương thấp nhất = 12939.6133
# Thế hệ 131: Lương hiện tại = 12939.6133
# Thế hệ 132: Lương thấp nhất = 12937.4533
# Thế hệ 132: Lương hiện tại = 12937.4533
# Thế hệ 133: Lương thấp nhất = 12937.4533
# Thế hệ 133: Lương hiện tại = 12938.5467
# Thế hệ 134: Lương thấp nhất = 12934.1733
# Thế hệ 134: Lương hiện tại = 12934.1733
# Thế hệ 135: Lương thấp nhất = 12934.1733
# Thế hệ 135: Lương hiện tại = 12935.6133
# Thế hệ 136: Lương thấp nhất = 12932.1733
# Thế hệ 136: Lương hiện tại = 12932.1733
# Thế hệ 137: Lương thấp nhất = 12931.9867
# Thế hệ 137: Lương hiện tại = 12931.9867
# Thế hệ 138: Lương thấp nhất = 12928.5733
# Thế hệ 138: Lương hiện tại = 12928.5733
# Thế hệ 139: Lương thấp nhất = 12910.0133
# Thế hệ 139: Lương hiện tại = 12910.0133
# Thế hệ 140: Lương thấp nhất = 12910.0133
# Thế hệ 140: Lương hiện tại = 12925.6933
# Thế hệ 141: Lương thấp nhất = 12910.0133
# Thế hệ 141: Lương hiện tại = 12925.6933
# Thế hệ 142: Lương thấp nhất = 12910.0133
# Thế hệ 142: Lương hiện tại = 12925.3733
# Thế hệ 143: Lương thấp nhất = 12910.0133
# Thế hệ 143: Lương hiện tại = 12921.5333
# Thế hệ 144: Lương thấp nhất = 12910.0133
# Thế hệ 144: Lương hiện tại = 12922.4933
# Thế hệ 145: Lương thấp nhất = 12910.0133
# Thế hệ 145: Lương hiện tại = 12921.8533
# Thế hệ 146: Lương thấp nhất = 12910.0133
# Thế hệ 146: Lương hiện tại = 12921.8533
# Thế hệ 147: Lương thấp nhất = 12910.0133
# Thế hệ 147: Lương hiện tại = 12919.4533
# Thế hệ 148: Lương thấp nhất = 12910.0133
# Thế hệ 148: Lương hiện tại = 12919.4533
# Thế hệ 149: Lương thấp nhất = 12910.0133
# Thế hệ 149: Lương hiện tại = 12917.0533
# Thế hệ 150: Lương thấp nhất = 12906.8133
# Thế hệ 150: Lương hiện tại = 12906.8133
# Thế hệ 151: Lương thấp nhất = 12906.8133
# Thế hệ 151: Lương hiện tại = 12907.1333
# Thế hệ 152: Lương thấp nhất = 12906.8133
# Thế hệ 152: Lương hiện tại = 12907.1333
# Thế hệ 153: Lương thấp nhất = 12902.3333
# Thế hệ 153: Lương hiện tại = 12902.3333
# Thế hệ 154: Lương thấp nhất = 12902.3333
# Thế hệ 154: Lương hiện tại = 12903.6933
# Thế hệ 155: Lương thấp nhất = 12902.0933
# Thế hệ 155: Lương hiện tại = 12902.0933
# Thế hệ 156: Lương thấp nhất = 12901.6933
# Thế hệ 156: Lương hiện tại = 12901.6933
# Thế hệ 157: Lương thấp nhất = 12892.2800
# Thế hệ 157: Lương hiện tại = 12892.2800
# Thế hệ 158: Lương thấp nhất = 12892.2800
# Thế hệ 158: Lương hiện tại = 12892.2800
# Thế hệ 159: Lương thấp nhất = 12892.2800
# Thế hệ 159: Lương hiện tại = 12892.2800
# Thế hệ 160: Lương thấp nhất = 12890.2800
# Thế hệ 160: Lương hiện tại = 12890.2800
# Thế hệ 161: Lương thấp nhất = 12889.0000
# Thế hệ 161: Lương hiện tại = 12889.0000
# Thế hệ 162: Lương thấp nhất = 12887.8800
# Thế hệ 162: Lương hiện tại = 12887.8800
# Thế hệ 163: Lương thấp nhất = 12886.2800
# Thế hệ 163: Lương hiện tại = 12886.2800
# Thế hệ 164: Lương thấp nhất = 12885.6400
# Thế hệ 164: Lương hiện tại = 12885.6400
# Thế hệ 165: Lương thấp nhất = 12884.0400
# Thế hệ 165: Lương hiện tại = 12884.0400
# Thế hệ 166: Lương thấp nhất = 12880.1200
# Thế hệ 166: Lương hiện tại = 12880.1200
# Thế hệ 167: Lương thấp nhất = 12871.3200
# Thế hệ 167: Lương hiện tại = 12871.3200
# Thế hệ 168: Lương thấp nhất = 12869.3200
# Thế hệ 168: Lương hiện tại = 12869.3200
# Thế hệ 169: Lương thấp nhất = 12867.7200
# Thế hệ 169: Lương hiện tại = 12867.7200
# Thế hệ 170: Lương thấp nhất = 12867.7200
# Thế hệ 170: Lương hiện tại = 12867.7200
# Thế hệ 171: Lương thấp nhất = 12867.7200
# Thế hệ 171: Lương hiện tại = 12867.7200
# Thế hệ 172: Lương thấp nhất = 12865.4800
# Thế hệ 172: Lương hiện tại = 12865.4800
# Thế hệ 173: Lương thấp nhất = 12865.4800
# Thế hệ 173: Lương hiện tại = 12865.4800
# Thế hệ 174: Lương thấp nhất = 12863.8800
# Thế hệ 174: Lương hiện tại = 12863.8800
# Thế hệ 175: Lương thấp nhất = 12854.7600
# Thế hệ 175: Lương hiện tại = 12854.7600
# Thế hệ 176: Lương thấp nhất = 12850.9200
# Thế hệ 176: Lương hiện tại = 12850.9200
# Thế hệ 177: Lương thấp nhất = 12850.9200
# Thế hệ 177: Lương hiện tại = 12850.9200
# Thế hệ 178: Lương thấp nhất = 12850.9200
# Thế hệ 178: Lương hiện tại = 12850.9200
# Thế hệ 179: Lương thấp nhất = 12849.3200
# Thế hệ 179: Lương hiện tại = 12849.3200
# Thế hệ 180: Lương thấp nhất = 12849.3200
# Thế hệ 180: Lương hiện tại = 12849.3200
# Thế hệ 181: Lương thấp nhất = 12849.3200
# Thế hệ 181: Lương hiện tại = 12849.3200
# Thế hệ 182: Lương thấp nhất = 12849.3200
# Thế hệ 182: Lương hiện tại = 12849.3200
# Thế hệ 183: Lương thấp nhất = 12849.3200
# Thế hệ 183: Lương hiện tại = 12849.3200
# Thế hệ 184: Lương thấp nhất = 12849.3200
# Thế hệ 184: Lương hiện tại = 12849.3200
# Thế hệ 185: Lương thấp nhất = 12849.3200
# Thế hệ 185: Lương hiện tại = 12849.3200
# Thế hệ 186: Lương thấp nhất = 12849.3200
# Thế hệ 186: Lương hiện tại = 12849.3200
# Thế hệ 187: Lương thấp nhất = 12849.3200
# Thế hệ 187: Lương hiện tại = 12849.3200
# Thế hệ 188: Lương thấp nhất = 12849.3200
# Thế hệ 188: Lương hiện tại = 12849.3200
# Thế hệ 189: Lương thấp nhất = 12849.3200
# Thế hệ 189: Lương hiện tại = 12849.3200
# Thế hệ 190: Lương thấp nhất = 12849.3200
# Thế hệ 190: Lương hiện tại = 12849.3200
# Thế hệ 191: Lương thấp nhất = 12849.3200
# Thế hệ 191: Lương hiện tại = 12849.3200
# Thế hệ 192: Lương thấp nhất = 12849.3200
# Thế hệ 192: Lương hiện tại = 12849.3200
# Thế hệ 193: Lương thấp nhất = 12849.3200
# Thế hệ 193: Lương hiện tại = 12849.3200
# Thế hệ 194: Lương thấp nhất = 12849.3200
# Thế hệ 194: Lương hiện tại = 12849.3200
# Thế hệ 195: Lương thấp nhất = 12849.3200
# Thế hệ 195: Lương hiện tại = 12849.3200
# Thế hệ 196: Lương thấp nhất = 12849.3200
# Thế hệ 196: Lương hiện tại = 12849.3200
# Thế hệ 197: Lương thấp nhất = 12849.3200
# Thế hệ 197: Lương hiện tại = 12849.3200
# Thế hệ 198: Lương thấp nhất = 12849.3200
# Thế hệ 198: Lương hiện tại = 12849.3200
# Thế hệ 199: Lương thấp nhất = 12849.3200
# Thế hệ 199: Lương hiện tại = 12849.3200
# Thế hệ 200: Lương thấp nhất = 12849.3200
# Thế hệ 200: Lương hiện tại = 12849.3200
# Thế hệ 201: Lương thấp nhất = 12849.3200
# Thế hệ 201: Lương hiện tại = 12849.3200
# Thế hệ 202: Lương thấp nhất = 12849.3200
# Thế hệ 202: Lương hiện tại = 12849.3200
# Thế hệ 203: Lương thấp nhất = 12849.3200
# Thế hệ 203: Lương hiện tại = 12849.3200
# Thế hệ 204: Lương thấp nhất = 12849.3200
# Thế hệ 204: Lương hiện tại = 12849.3200
# Thế hệ 205: Lương thấp nhất = 12849.3200
# Thế hệ 205: Lương hiện tại = 12849.3200
# Thế hệ 206: Lương thấp nhất = 12849.3200
# Thế hệ 206: Lương hiện tại = 12849.3200
# Thế hệ 207: Lương thấp nhất = 12849.3200
# Thế hệ 207: Lương hiện tại = 12849.3200
# Thế hệ 208: Lương thấp nhất = 12849.3200
# Thế hệ 208: Lương hiện tại = 12849.3200
# Thế hệ 209: Lương thấp nhất = 12849.3200
# Thế hệ 209: Lương hiện tại = 12849.3200
# Thế hệ 210: Lương thấp nhất = 12849.3200
# Thế hệ 210: Lương hiện tại = 12849.3200
# Thế hệ 211: Lương thấp nhất = 12849.3200
# Thế hệ 211: Lương hiện tại = 12849.3200
# Thế hệ 212: Lương thấp nhất = 12849.3200
# Thế hệ 212: Lương hiện tại = 12849.3200
# Thế hệ 213: Lương thấp nhất = 12849.3200
# Thế hệ 213: Lương hiện tại = 12849.3200
# Thế hệ 214: Lương thấp nhất = 12849.3200
# Thế hệ 214: Lương hiện tại = 12849.3200
# Thế hệ 215: Lương thấp nhất = 12849.3200
# Thế hệ 215: Lương hiện tại = 12849.3200
# Thế hệ 216: Lương thấp nhất = 12849.3200
# Thế hệ 216: Lương hiện tại = 12849.3200
# Thế hệ 217: Lương thấp nhất = 12849.3200
# Thế hệ 217: Lương hiện tại = 12849.3200
# Thế hệ 218: Lương thấp nhất = 12849.3200
# Thế hệ 218: Lương hiện tại = 12849.3200
# Thế hệ 219: Lương thấp nhất = 12849.3200
# Thế hệ 219: Lương hiện tại = 12849.3200
# Thế hệ 220: Lương thấp nhất = 12849.3200
# Thế hệ 220: Lương hiện tại = 12849.3200
# Thế hệ 221: Lương thấp nhất = 12849.3200
# Thế hệ 221: Lương hiện tại = 12849.3200
# Thế hệ 222: Lương thấp nhất = 12849.3200
# Thế hệ 222: Lương hiện tại = 12849.3200
# Thế hệ 223: Lương thấp nhất = 12849.3200
# Thế hệ 223: Lương hiện tại = 12849.3200
# Thế hệ 224: Lương thấp nhất = 12849.3200
# Thế hệ 224: Lương hiện tại = 12849.3200
# Thế hệ 225: Lương thấp nhất = 12849.3200
# Thế hệ 225: Lương hiện tại = 12849.3200
# Thế hệ 226: Lương thấp nhất = 12849.3200
# Thế hệ 226: Lương hiện tại = 12849.3200
# Thế hệ 227: Lương thấp nhất = 12849.3200
# Thế hệ 227: Lương hiện tại = 12849.3200
# Thế hệ 228: Lương thấp nhất = 12849.3200
# Thế hệ 228: Lương hiện tại = 12849.3200
# Thế hệ 229: Lương thấp nhất = 12849.3200
# Thế hệ 229: Lương hiện tại = 12849.3200
# Thế hệ 230: Lương thấp nhất = 12849.3200
# Thế hệ 230: Lương hiện tại = 12849.3200
# Thế hệ 231: Lương thấp nhất = 12849.3200
# Thế hệ 231: Lương hiện tại = 12849.3200
# Thế hệ 232: Lương thấp nhất = 12849.3200
# Thế hệ 232: Lương hiện tại = 12849.3200
# Thế hệ 233: Lương thấp nhất = 12849.3200
# Thế hệ 233: Lương hiện tại = 12849.3200
# Thế hệ 234: Lương thấp nhất = 12849.3200
# Thế hệ 234: Lương hiện tại = 12849.3200
# Thế hệ 235: Lương thấp nhất = 12849.3200
# Thế hệ 235: Lương hiện tại = 12849.3200
# Thế hệ 236: Lương thấp nhất = 12849.3200
# Thế hệ 236: Lương hiện tại = 12849.3200
# Thế hệ 237: Lương thấp nhất = 12849.3200
# Thế hệ 237: Lương hiện tại = 12849.3200
# Thế hệ 238: Lương thấp nhất = 12849.3200
# Thế hệ 238: Lương hiện tại = 12849.3200
# Thế hệ 239: Lương thấp nhất = 12849.3200
# Thế hệ 239: Lương hiện tại = 12849.3200
# Thế hệ 240: Lương thấp nhất = 12849.3200
# Thế hệ 240: Lương hiện tại = 12849.3200
# Thế hệ 241: Lương thấp nhất = 12849.3200
# Thế hệ 241: Lương hiện tại = 12849.3200
# Thế hệ 242: Lương thấp nhất = 12849.3200
# Thế hệ 242: Lương hiện tại = 12849.3200
# Thế hệ 243: Lương thấp nhất = 12849.3200
# Thế hệ 243: Lương hiện tại = 12849.3200
# Thế hệ 244: Lương thấp nhất = 12849.3200
# Thế hệ 244: Lương hiện tại = 12849.3200
# Thế hệ 245: Lương thấp nhất = 12849.3200
# Thế hệ 245: Lương hiện tại = 12849.3200
# Thế hệ 246: Lương thấp nhất = 12849.3200
# Thế hệ 246: Lương hiện tại = 12849.3200
# Thế hệ 247: Lương thấp nhất = 12849.3200
# Thế hệ 247: Lương hiện tại = 12849.3200
# Thế hệ 248: Lương thấp nhất = 12849.3200
# Thế hệ 248: Lương hiện tại = 12849.3200
# Thế hệ 249: Lương thấp nhất = 12849.3200
# Thế hệ 249: Lương hiện tại = 12849.3200
# Thế hệ 250: Lương thấp nhất = 12849.3200
# Thế hệ 250: Lương hiện tại = 12849.3200
# Thế hệ 251: Lương thấp nhất = 12849.3200
# Thế hệ 251: Lương hiện tại = 12849.3200
# Thế hệ 252: Lương thấp nhất = 12849.3200
# Thế hệ 252: Lương hiện tại = 12849.3200
# Thế hệ 253: Lương thấp nhất = 12849.3200
# Thế hệ 253: Lương hiện tại = 12849.3200
# Thế hệ 254: Lương thấp nhất = 12849.3200
# Thế hệ 254: Lương hiện tại = 12849.3200
# Thế hệ 255: Lương thấp nhất = 12849.3200
# Thế hệ 255: Lương hiện tại = 12849.3200
# Thế hệ 256: Lương thấp nhất = 12849.3200
# Thế hệ 256: Lương hiện tại = 12849.3200
# Thế hệ 257: Lương thấp nhất = 12849.3200
# Thế hệ 257: Lương hiện tại = 12849.3200
# Thế hệ 258: Lương thấp nhất = 12849.3200
# Thế hệ 258: Lương hiện tại = 12849.3200
# Thế hệ 259: Lương thấp nhất = 12849.3200
# Thế hệ 259: Lương hiện tại = 12849.3200
# Thế hệ 260: Lương thấp nhất = 12849.3200
# Thế hệ 260: Lương hiện tại = 12849.3200
# Thế hệ 261: Lương thấp nhất = 12849.3200
# Thế hệ 261: Lương hiện tại = 12849.3200
# Thế hệ 262: Lương thấp nhất = 12849.3200
# Thế hệ 262: Lương hiện tại = 12849.3200
# Thế hệ 263: Lương thấp nhất = 12849.3200
# Thế hệ 263: Lương hiện tại = 12849.3200
# Thế hệ 264: Lương thấp nhất = 12849.3200
# Thế hệ 264: Lương hiện tại = 12849.3200
# Thế hệ 265: Lương thấp nhất = 12849.3200
# Thế hệ 265: Lương hiện tại = 12849.3200
# Thế hệ 266: Lương thấp nhất = 12849.3200
# Thế hệ 266: Lương hiện tại = 12849.3200
# Thế hệ 267: Lương thấp nhất = 12849.3200
# Thế hệ 267: Lương hiện tại = 12849.3200
# Thế hệ 268: Lương thấp nhất = 12849.3200
# Thế hệ 268: Lương hiện tại = 12849.3200
# Thế hệ 269: Lương thấp nhất = 12849.3200
# Thế hệ 269: Lương hiện tại = 12849.3200
# Thế hệ 270: Lương thấp nhất = 12849.3200
# Thế hệ 270: Lương hiện tại = 12849.3200
# Thế hệ 271: Lương thấp nhất = 12849.3200
# Thế hệ 271: Lương hiện tại = 12849.3200
# Thế hệ 272: Lương thấp nhất = 12849.3200
# Thế hệ 272: Lương hiện tại = 12849.3200
# Thế hệ 273: Lương thấp nhất = 12849.3200
# Thế hệ 273: Lương hiện tại = 12849.3200
# Thế hệ 274: Lương thấp nhất = 12849.3200
# Thế hệ 274: Lương hiện tại = 12849.3200
# Thế hệ 275: Lương thấp nhất = 12849.3200
# Thế hệ 275: Lương hiện tại = 12849.3200
# Thế hệ 276: Lương thấp nhất = 12849.3200
# Thế hệ 276: Lương hiện tại = 12849.3200
# Thế hệ 277: Lương thấp nhất = 12849.3200
# Thế hệ 277: Lương hiện tại = 12849.3200
# Thế hệ 278: Lương thấp nhất = 12849.3200
# Thế hệ 278: Lương hiện tại = 12849.3200
# Thế hệ 279: Lương thấp nhất = 12849.3200
# Thế hệ 279: Lương hiện tại = 12849.3200
# Thế hệ 280: Lương thấp nhất = 12849.3200
# Thế hệ 280: Lương hiện tại = 12849.3200
# Thế hệ 281: Lương thấp nhất = 12849.3200
# Thế hệ 281: Lương hiện tại = 12849.3200
# Thế hệ 282: Lương thấp nhất = 12849.3200
# Thế hệ 282: Lương hiện tại = 12849.3200
# Thế hệ 283: Lương thấp nhất = 12849.3200
# Thế hệ 283: Lương hiện tại = 12849.3200
# Thế hệ 284: Lương thấp nhất = 12849.3200
# Thế hệ 284: Lương hiện tại = 12849.3200
# Thế hệ 285: Lương thấp nhất = 12849.3200
# Thế hệ 285: Lương hiện tại = 12849.3200
# Thế hệ 286: Lương thấp nhất = 12849.3200
# Thế hệ 286: Lương hiện tại = 12849.3200
# Thế hệ 287: Lương thấp nhất = 12849.3200
# Thế hệ 287: Lương hiện tại = 12849.3200
# Thế hệ 288: Lương thấp nhất = 12849.3200
# Thế hệ 288: Lương hiện tại = 12849.3200
# Thế hệ 289: Lương thấp nhất = 12849.3200
# Thế hệ 289: Lương hiện tại = 12849.3200
# Thế hệ 290: Lương thấp nhất = 12849.3200
# Thế hệ 290: Lương hiện tại = 12849.3200
# Thế hệ 291: Lương thấp nhất = 12849.3200
# Thế hệ 291: Lương hiện tại = 12849.3200
# Thế hệ 292: Lương thấp nhất = 12849.3200
# Thế hệ 292: Lương hiện tại = 12849.3200
# Thế hệ 293: Lương thấp nhất = 12849.3200
# Thế hệ 293: Lương hiện tại = 12849.3200
# Thế hệ 294: Lương thấp nhất = 12849.3200
# Thế hệ 294: Lương hiện tại = 12849.3200
# Thế hệ 295: Lương thấp nhất = 12849.3200
# Thế hệ 295: Lương hiện tại = 12849.3200
# Thế hệ 296: Lương thấp nhất = 12849.3200
# Thế hệ 296: Lương hiện tại = 12849.3200
# Thế hệ 297: Lương thấp nhất = 12849.3200
# Thế hệ 297: Lương hiện tại = 12849.3200
# Thế hệ 298: Lương thấp nhất = 12849.3200
# Thế hệ 298: Lương hiện tại = 12849.3200
# Thế hệ 299: Lương thấp nhất = 12849.3200
# Thế hệ 299: Lương hiện tại = 12849.3200
# Thế hệ 300: Lương thấp nhất = 12849.3200
# Thế hệ 300: Lương hiện tại = 12849.3200
# Thế hệ 301: Lương thấp nhất = 12849.3200
# Thế hệ 301: Lương hiện tại = 12849.3200
# Thế hệ 302: Lương thấp nhất = 12849.3200
# Thế hệ 302: Lương hiện tại = 12849.3200
# Thế hệ 303: Lương thấp nhất = 12849.3200
# Thế hệ 303: Lương hiện tại = 12849.3200
# Thế hệ 304: Lương thấp nhất = 12849.3200
# Thế hệ 304: Lương hiện tại = 12849.3200
# Thế hệ 305: Lương thấp nhất = 12849.3200
# Thế hệ 305: Lương hiện tại = 12849.3200
# Thế hệ 306: Lương thấp nhất = 12849.3200
# Thế hệ 306: Lương hiện tại = 12849.3200
# Thế hệ 307: Lương thấp nhất = 12849.3200
# Thế hệ 307: Lương hiện tại = 12849.3200
# Thế hệ 308: Lương thấp nhất = 12849.3200
# Thế hệ 308: Lương hiện tại = 12849.3200
# Thế hệ 309: Lương thấp nhất = 12849.3200
# Thế hệ 309: Lương hiện tại = 12849.3200
# Thế hệ 310: Lương thấp nhất = 12849.3200
# Thế hệ 310: Lương hiện tại = 12849.3200
# Thế hệ 311: Lương thấp nhất = 12849.3200
# Thế hệ 311: Lương hiện tại = 12849.3200
# Thế hệ 312: Lương thấp nhất = 12849.3200
# Thế hệ 312: Lương hiện tại = 12849.3200
# Thế hệ 313: Lương thấp nhất = 12849.3200
# Thế hệ 313: Lương hiện tại = 12849.3200
# Thế hệ 314: Lương thấp nhất = 12849.3200
# Thế hệ 314: Lương hiện tại = 12849.3200
# Thế hệ 315: Lương thấp nhất = 12849.3200
# Thế hệ 315: Lương hiện tại = 12849.3200
# Thế hệ 316: Lương thấp nhất = 12849.3200
# Thế hệ 316: Lương hiện tại = 12849.3200
# Thế hệ 317: Lương thấp nhất = 12849.3200
# Thế hệ 317: Lương hiện tại = 12849.3200
# Thế hệ 318: Lương thấp nhất = 12849.3200
# Thế hệ 318: Lương hiện tại = 12849.3200
# Thế hệ 319: Lương thấp nhất = 12849.3200
# Thế hệ 319: Lương hiện tại = 12849.3200
# Thế hệ 320: Lương thấp nhất = 12849.3200
# Thế hệ 320: Lương hiện tại = 12849.3200
# Thế hệ 321: Lương thấp nhất = 12849.3200
# Thế hệ 321: Lương hiện tại = 12849.3200
# Thế hệ 322: Lương thấp nhất = 12849.3200
# Thế hệ 322: Lương hiện tại = 12849.3200
# Thế hệ 323: Lương thấp nhất = 12849.3200
# Thế hệ 323: Lương hiện tại = 12849.3200
# Thế hệ 324: Lương thấp nhất = 12849.3200
# Thế hệ 324: Lương hiện tại = 12849.3200
# Thế hệ 325: Lương thấp nhất = 12849.3200
# Thế hệ 325: Lương hiện tại = 12849.3200
# Thế hệ 326: Lương thấp nhất = 12849.3200
# Thế hệ 326: Lương hiện tại = 12849.3200
# Thế hệ 327: Lương thấp nhất = 12849.3200
# Thế hệ 327: Lương hiện tại = 12849.3200
# Thế hệ 328: Lương thấp nhất = 12849.3200
# Thế hệ 328: Lương hiện tại = 12849.3200
# Thế hệ 329: Lương thấp nhất = 12849.3200
# Thế hệ 329: Lương hiện tại = 12849.3200
# Thế hệ 330: Lương thấp nhất = 12849.3200
# Thế hệ 330: Lương hiện tại = 12849.3200
# Thế hệ 331: Lương thấp nhất = 12849.3200
# Thế hệ 331: Lương hiện tại = 12849.3200
# Thế hệ 332: Lương thấp nhất = 12849.3200
# Thế hệ 332: Lương hiện tại = 12849.3200
# Thế hệ 333: Lương thấp nhất = 12849.3200
# Thế hệ 333: Lương hiện tại = 12849.3200
# Thế hệ 334: Lương thấp nhất = 12849.3200
# Thế hệ 334: Lương hiện tại = 12849.3200
# Thế hệ 335: Lương thấp nhất = 12849.3200
# Thế hệ 335: Lương hiện tại = 12849.3200
# Thế hệ 336: Lương thấp nhất = 12849.3200
# Thế hệ 336: Lương hiện tại = 12849.3200
# Thế hệ 337: Lương thấp nhất = 12849.3200
# Thế hệ 337: Lương hiện tại = 12849.3200
# Thế hệ 338: Lương thấp nhất = 12849.3200
# Thế hệ 338: Lương hiện tại = 12849.3200
# Thế hệ 339: Lương thấp nhất = 12849.3200
# Thế hệ 339: Lương hiện tại = 12849.3200
# Thế hệ 340: Lương thấp nhất = 12849.3200
# Thế hệ 340: Lương hiện tại = 12849.3200
# Thế hệ 341: Lương thấp nhất = 12849.3200
# Thế hệ 341: Lương hiện tại = 12849.3200
# Thế hệ 342: Lương thấp nhất = 12849.3200
# Thế hệ 342: Lương hiện tại = 12849.3200
# Thế hệ 343: Lương thấp nhất = 12849.3200
# Thế hệ 343: Lương hiện tại = 12849.3200
# Thế hệ 344: Lương thấp nhất = 12849.3200
# Thế hệ 344: Lương hiện tại = 12849.3200
# Thế hệ 345: Lương thấp nhất = 12849.3200
# Thế hệ 345: Lương hiện tại = 12849.3200
# Thế hệ 346: Lương thấp nhất = 12849.3200
# Thế hệ 346: Lương hiện tại = 12849.3200
# Thế hệ 347: Lương thấp nhất = 12849.3200
# Thế hệ 347: Lương hiện tại = 12849.3200
# Thế hệ 348: Lương thấp nhất = 12849.3200
# Thế hệ 348: Lương hiện tại = 12849.3200
# Thế hệ 349: Lương thấp nhất = 12849.3200
# Thế hệ 349: Lương hiện tại = 12849.3200
# Thế hệ 350: Lương thấp nhất = 12849.3200
# Thế hệ 350: Lương hiện tại = 12849.3200
# Thế hệ 351: Lương thấp nhất = 12849.3200
# Thế hệ 351: Lương hiện tại = 12849.3200
# Thế hệ 352: Lương thấp nhất = 12849.3200
# Thế hệ 352: Lương hiện tại = 12849.3200
# Thế hệ 353: Lương thấp nhất = 12849.3200
# Thế hệ 353: Lương hiện tại = 12849.3200
# Thế hệ 354: Lương thấp nhất = 12849.3200
# Thế hệ 354: Lương hiện tại = 12849.3200
# Thế hệ 355: Lương thấp nhất = 12849.3200
# Thế hệ 355: Lương hiện tại = 12849.3200
# Thế hệ 356: Lương thấp nhất = 12849.3200
# Thế hệ 356: Lương hiện tại = 12849.3200
# Thế hệ 357: Lương thấp nhất = 12849.3200
# Thế hệ 357: Lương hiện tại = 12849.3200
# Thế hệ 358: Lương thấp nhất = 12849.3200
# Thế hệ 358: Lương hiện tại = 12849.3200
# Thế hệ 359: Lương thấp nhất = 12849.3200
# Thế hệ 359: Lương hiện tại = 12849.3200
# Thế hệ 360: Lương thấp nhất = 12849.3200
# Thế hệ 360: Lương hiện tại = 12849.3200
# Thế hệ 361: Lương thấp nhất = 12849.3200
# Thế hệ 361: Lương hiện tại = 12849.3200
# Thế hệ 362: Lương thấp nhất = 12849.3200
# Thế hệ 362: Lương hiện tại = 12849.3200
# Thế hệ 363: Lương thấp nhất = 12849.3200
# Thế hệ 363: Lương hiện tại = 12849.3200
# Thế hệ 364: Lương thấp nhất = 12849.3200
# Thế hệ 364: Lương hiện tại = 12849.3200
# Thế hệ 365: Lương thấp nhất = 12849.3200
# Thế hệ 365: Lương hiện tại = 12849.3200
# Thế hệ 366: Lương thấp nhất = 12849.3200
# Thế hệ 366: Lương hiện tại = 12849.3200
# Thế hệ 367: Lương thấp nhất = 12849.3200
# Thế hệ 367: Lương hiện tại = 12849.3200
# Thế hệ 368: Lương thấp nhất = 12849.3200
# Thế hệ 368: Lương hiện tại = 12849.3200
# Thế hệ 369: Lương thấp nhất = 12849.3200
# Thế hệ 369: Lương hiện tại = 12849.3200
# Thế hệ 370: Lương thấp nhất = 12849.3200
# Thế hệ 370: Lương hiện tại = 12849.3200
# Thế hệ 371: Lương thấp nhất = 12849.3200
# Thế hệ 371: Lương hiện tại = 12849.3200
# Thế hệ 372: Lương thấp nhất = 12849.3200
# Thế hệ 372: Lương hiện tại = 12849.3200
# Thế hệ 373: Lương thấp nhất = 12849.3200
# Thế hệ 373: Lương hiện tại = 12849.3200
# Thế hệ 374: Lương thấp nhất = 12849.3200
# Thế hệ 374: Lương hiện tại = 12849.3200
# Thế hệ 375: Lương thấp nhất = 12849.3200
# Thế hệ 375: Lương hiện tại = 12849.3200
# Thế hệ 376: Lương thấp nhất = 12849.3200
# Thế hệ 376: Lương hiện tại = 12849.3200
# Thế hệ 377: Lương thấp nhất = 12849.3200
# Thế hệ 377: Lương hiện tại = 12849.3200
# Thế hệ 378: Lương thấp nhất = 12849.3200
# Thế hệ 378: Lương hiện tại = 12849.3200
# Thế hệ 379: Lương thấp nhất = 12849.3200
# Thế hệ 379: Lương hiện tại = 12849.3200
# Thế hệ 380: Lương thấp nhất = 12849.3200
# Thế hệ 380: Lương hiện tại = 12849.3200
# Thế hệ 381: Lương thấp nhất = 12849.3200
# Thế hệ 381: Lương hiện tại = 12849.3200
# Thế hệ 382: Lương thấp nhất = 12849.3200
# Thế hệ 382: Lương hiện tại = 12849.3200
# Thế hệ 383: Lương thấp nhất = 12849.3200
# Thế hệ 383: Lương hiện tại = 12849.3200
# Thế hệ 384: Lương thấp nhất = 12849.3200
# Thế hệ 384: Lương hiện tại = 12849.3200
# Thế hệ 385: Lương thấp nhất = 12849.3200
# Thế hệ 385: Lương hiện tại = 12849.3200
# Thế hệ 386: Lương thấp nhất = 12849.3200
# Thế hệ 386: Lương hiện tại = 12849.3200
# Thế hệ 387: Lương thấp nhất = 12849.3200
# Thế hệ 387: Lương hiện tại = 12849.3200
# Thế hệ 388: Lương thấp nhất = 12849.3200
# Thế hệ 388: Lương hiện tại = 12849.3200
# Thế hệ 389: Lương thấp nhất = 12849.3200
# Thế hệ 389: Lương hiện tại = 12849.3200
# Thế hệ 390: Lương thấp nhất = 12849.3200
# Thế hệ 390: Lương hiện tại = 12849.3200
# Thế hệ 391: Lương thấp nhất = 12849.3200
# Thế hệ 391: Lương hiện tại = 12849.3200
# Thế hệ 392: Lương thấp nhất = 12849.3200
# Thế hệ 392: Lương hiện tại = 12849.3200
# Thế hệ 393: Lương thấp nhất = 12849.3200
# Thế hệ 393: Lương hiện tại = 12849.3200
# Thế hệ 394: Lương thấp nhất = 12849.3200
# Thế hệ 394: Lương hiện tại = 12849.3200
# Thế hệ 395: Lương thấp nhất = 12849.3200
# Thế hệ 395: Lương hiện tại = 12849.3200
# Thế hệ 396: Lương thấp nhất = 12849.3200
# Thế hệ 396: Lương hiện tại = 12849.3200
# Thế hệ 397: Lương thấp nhất = 12849.3200
# Thế hệ 397: Lương hiện tại = 12849.3200
# Thế hệ 398: Lương thấp nhất = 12849.3200
# Thế hệ 398: Lương hiện tại = 12849.3200
# Thế hệ 399: Lương thấp nhất = 12849.3200
# Thế hệ 399: Lương hiện tại = 12849.3200
# Thế hệ 400: Lương thấp nhất = 12849.3200
# Thế hệ 400: Lương hiện tại = 12849.3200
# Thế hệ 401: Lương thấp nhất = 12849.3200
# Thế hệ 401: Lương hiện tại = 12849.3200
# Thế hệ 402: Lương thấp nhất = 12849.3200
# Thế hệ 402: Lương hiện tại = 12849.3200
# Thế hệ 403: Lương thấp nhất = 12849.3200
# Thế hệ 403: Lương hiện tại = 12849.3200
# Thế hệ 404: Lương thấp nhất = 12849.3200
# Thế hệ 404: Lương hiện tại = 12849.3200
# Thế hệ 405: Lương thấp nhất = 12849.3200
# Thế hệ 405: Lương hiện tại = 12849.3200
# Thế hệ 406: Lương thấp nhất = 12849.3200
# Thế hệ 406: Lương hiện tại = 12849.3200
# Thế hệ 407: Lương thấp nhất = 12849.3200
# Thế hệ 407: Lương hiện tại = 12849.3200
# Thế hệ 408: Lương thấp nhất = 12849.3200
# Thế hệ 408: Lương hiện tại = 12849.3200
# Thế hệ 409: Lương thấp nhất = 12849.3200
# Thế hệ 409: Lương hiện tại = 12849.3200
# Thế hệ 410: Lương thấp nhất = 12849.3200
# Thế hệ 410: Lương hiện tại = 12849.3200
# Thế hệ 411: Lương thấp nhất = 12849.3200
# Thế hệ 411: Lương hiện tại = 12849.3200
# Thế hệ 412: Lương thấp nhất = 12849.3200
# Thế hệ 412: Lương hiện tại = 12849.3200
# Thế hệ 413: Lương thấp nhất = 12849.3200
# Thế hệ 413: Lương hiện tại = 12849.3200
# Thế hệ 414: Lương thấp nhất = 12849.3200
# Thế hệ 414: Lương hiện tại = 12849.3200
# Thế hệ 415: Lương thấp nhất = 12849.3200
# Thế hệ 415: Lương hiện tại = 12849.3200
# Thế hệ 416: Lương thấp nhất = 12849.3200
# Thế hệ 416: Lương hiện tại = 12849.3200
# Thế hệ 417: Lương thấp nhất = 12849.3200
# Thế hệ 417: Lương hiện tại = 12849.3200
# Thế hệ 418: Lương thấp nhất = 12849.3200
# Thế hệ 418: Lương hiện tại = 12849.3200
# Thế hệ 419: Lương thấp nhất = 12849.3200
# Thế hệ 419: Lương hiện tại = 12849.3200
# Thế hệ 420: Lương thấp nhất = 12849.3200
# Thế hệ 420: Lương hiện tại = 12849.3200
# Thế hệ 421: Lương thấp nhất = 12849.3200
# Thế hệ 421: Lương hiện tại = 12849.3200
# Thế hệ 422: Lương thấp nhất = 12849.3200
# Thế hệ 422: Lương hiện tại = 12849.3200
# Thế hệ 423: Lương thấp nhất = 12849.3200
# Thế hệ 423: Lương hiện tại = 12849.3200
# Thế hệ 424: Lương thấp nhất = 12849.3200
# Thế hệ 424: Lương hiện tại = 12849.3200
# Thế hệ 425: Lương thấp nhất = 12849.3200
# Thế hệ 425: Lương hiện tại = 12849.3200
# Thế hệ 426: Lương thấp nhất = 12849.3200
# Thế hệ 426: Lương hiện tại = 12849.3200
# Thế hệ 427: Lương thấp nhất = 12849.3200
# Thế hệ 427: Lương hiện tại = 12849.3200
# Thế hệ 428: Lương thấp nhất = 12849.3200
# Thế hệ 428: Lương hiện tại = 12849.3200
# Thế hệ 429: Lương thấp nhất = 12849.3200
# Thế hệ 429: Lương hiện tại = 12849.3200
# Thế hệ 430: Lương thấp nhất = 12849.3200
# Thế hệ 430: Lương hiện tại = 12849.3200
# Thế hệ 431: Lương thấp nhất = 12849.3200
# Thế hệ 431: Lương hiện tại = 12849.3200
# Thế hệ 432: Lương thấp nhất = 12849.3200
# Thế hệ 432: Lương hiện tại = 12849.3200
# Thế hệ 433: Lương thấp nhất = 12849.3200
# Thế hệ 433: Lương hiện tại = 12849.3200
# Thế hệ 434: Lương thấp nhất = 12849.3200
# Thế hệ 434: Lương hiện tại = 12849.3200
# Thế hệ 435: Lương thấp nhất = 12849.3200
# Thế hệ 435: Lương hiện tại = 12849.3200
# Thế hệ 436: Lương thấp nhất = 12849.3200
# Thế hệ 436: Lương hiện tại = 12849.3200
# Thế hệ 437: Lương thấp nhất = 12849.3200
# Thế hệ 437: Lương hiện tại = 12849.3200
# Thế hệ 438: Lương thấp nhất = 12849.3200
# Thế hệ 438: Lương hiện tại = 12849.3200
# Thế hệ 439: Lương thấp nhất = 12849.3200
# Thế hệ 439: Lương hiện tại = 12849.3200
# Thế hệ 440: Lương thấp nhất = 12849.3200
# Thế hệ 440: Lương hiện tại = 12849.3200
# Thế hệ 441: Lương thấp nhất = 12849.3200
# Thế hệ 441: Lương hiện tại = 12849.3200
# Thế hệ 442: Lương thấp nhất = 12849.3200
# Thế hệ 442: Lương hiện tại = 12849.3200
# Thế hệ 443: Lương thấp nhất = 12849.3200
# Thế hệ 443: Lương hiện tại = 12849.3200
# Thế hệ 444: Lương thấp nhất = 12849.3200
# Thế hệ 444: Lương hiện tại = 12849.3200
# Thế hệ 445: Lương thấp nhất = 12849.3200
# Thế hệ 445: Lương hiện tại = 12849.3200
# Thế hệ 446: Lương thấp nhất = 12849.3200
# Thế hệ 446: Lương hiện tại = 12849.3200
# Thế hệ 447: Lương thấp nhất = 12849.3200
# Thế hệ 447: Lương hiện tại = 12849.3200
# Thế hệ 448: Lương thấp nhất = 12849.3200
# Thế hệ 448: Lương hiện tại = 12849.3200
# Thế hệ 449: Lương thấp nhất = 12849.3200
# Thế hệ 449: Lương hiện tại = 12849.3200
# Thế hệ 450: Lương thấp nhất = 12849.3200
# Thế hệ 450: Lương hiện tại = 12849.3200
# Thế hệ 451: Lương thấp nhất = 12849.3200
# Thế hệ 451: Lương hiện tại = 12849.3200
# Thế hệ 452: Lương thấp nhất = 12849.3200
# Thế hệ 452: Lương hiện tại = 12849.3200
# Thế hệ 453: Lương thấp nhất = 12849.3200
# Thế hệ 453: Lương hiện tại = 12849.3200
# Thế hệ 454: Lương thấp nhất = 12849.3200
# Thế hệ 454: Lương hiện tại = 12849.3200
# Thế hệ 455: Lương thấp nhất = 12849.3200
# Thế hệ 455: Lương hiện tại = 12849.3200
# Thế hệ 456: Lương thấp nhất = 12849.3200
# Thế hệ 456: Lương hiện tại = 12849.3200
# Thế hệ 457: Lương thấp nhất = 12849.3200
# Thế hệ 457: Lương hiện tại = 12849.3200
# Thế hệ 458: Lương thấp nhất = 12849.3200
# Thế hệ 458: Lương hiện tại = 12849.3200
# Thế hệ 459: Lương thấp nhất = 12849.3200
# Thế hệ 459: Lương hiện tại = 12849.3200
# Thế hệ 460: Lương thấp nhất = 12849.3200
# Thế hệ 460: Lương hiện tại = 12849.3200
# Thế hệ 461: Lương thấp nhất = 12849.3200
# Thế hệ 461: Lương hiện tại = 12849.3200
# Thế hệ 462: Lương thấp nhất = 12849.3200
# Thế hệ 462: Lương hiện tại = 12849.3200
# Thế hệ 463: Lương thấp nhất = 12849.3200
# Thế hệ 463: Lương hiện tại = 12849.3200
# Thế hệ 464: Lương thấp nhất = 12849.3200
# Thế hệ 464: Lương hiện tại = 12849.3200
# Thế hệ 465: Lương thấp nhất = 12849.3200
# Thế hệ 465: Lương hiện tại = 12849.3200
# Thế hệ 466: Lương thấp nhất = 12849.3200
# Thế hệ 466: Lương hiện tại = 12849.3200
# Thế hệ 467: Lương thấp nhất = 12849.3200
# Thế hệ 467: Lương hiện tại = 12849.3200
# Thế hệ 468: Lương thấp nhất = 12849.3200
# Thế hệ 468: Lương hiện tại = 12849.3200
# Thế hệ 469: Lương thấp nhất = 12849.3200
# Thế hệ 469: Lương hiện tại = 12849.3200
# Thế hệ 470: Lương thấp nhất = 12849.3200
# Thế hệ 470: Lương hiện tại = 12849.3200
# Thế hệ 471: Lương thấp nhất = 12849.3200
# Thế hệ 471: Lương hiện tại = 12849.3200
# Thế hệ 472: Lương thấp nhất = 12849.3200
# Thế hệ 472: Lương hiện tại = 12849.3200
# Thế hệ 473: Lương thấp nhất = 12849.3200
# Thế hệ 473: Lương hiện tại = 12849.3200
# Thế hệ 474: Lương thấp nhất = 12849.3200
# Thế hệ 474: Lương hiện tại = 12849.3200
# Thế hệ 475: Lương thấp nhất = 12849.3200
# Thế hệ 475: Lương hiện tại = 12849.3200
# Thế hệ 476: Lương thấp nhất = 12849.3200
# Thế hệ 476: Lương hiện tại = 12849.3200
# Thế hệ 477: Lương thấp nhất = 12849.3200
# Thế hệ 477: Lương hiện tại = 12849.3200
# Thế hệ 478: Lương thấp nhất = 12849.3200
# Thế hệ 478: Lương hiện tại = 12849.3200
# Thế hệ 479: Lương thấp nhất = 12849.3200
# Thế hệ 479: Lương hiện tại = 12849.3200
# Thế hệ 480: Lương thấp nhất = 12849.3200
# Thế hệ 480: Lương hiện tại = 12849.3200
# Thế hệ 481: Lương thấp nhất = 12849.3200
# Thế hệ 481: Lương hiện tại = 12849.3200
# Thế hệ 482: Lương thấp nhất = 12849.3200
# Thế hệ 482: Lương hiện tại = 12849.3200
# Thế hệ 483: Lương thấp nhất = 12849.3200
# Thế hệ 483: Lương hiện tại = 12849.3200
# Thế hệ 484: Lương thấp nhất = 12849.3200
# Thế hệ 484: Lương hiện tại = 12849.3200
# Thế hệ 485: Lương thấp nhất = 12849.3200
# Thế hệ 485: Lương hiện tại = 12849.3200
# Thế hệ 486: Lương thấp nhất = 12849.3200
# Thế hệ 486: Lương hiện tại = 12849.3200
# Thế hệ 487: Lương thấp nhất = 12849.3200
# Thế hệ 487: Lương hiện tại = 12849.3200
# Thế hệ 488: Lương thấp nhất = 12849.3200
# Thế hệ 488: Lương hiện tại = 12849.3200
# Thế hệ 489: Lương thấp nhất = 12849.3200
# Thế hệ 489: Lương hiện tại = 12849.3200
# Thế hệ 490: Lương thấp nhất = 12849.3200
# Thế hệ 490: Lương hiện tại = 12849.3200
# Thế hệ 491: Lương thấp nhất = 12849.3200
# Thế hệ 491: Lương hiện tại = 12849.3200
# Thế hệ 492: Lương thấp nhất = 12849.3200
# Thế hệ 492: Lương hiện tại = 12849.3200
# Thế hệ 493: Lương thấp nhất = 12849.3200
# Thế hệ 493: Lương hiện tại = 12849.3200
# Thế hệ 494: Lương thấp nhất = 12849.3200
# Thế hệ 494: Lương hiện tại = 12849.3200
# Thế hệ 495: Lương thấp nhất = 12849.3200
# Thế hệ 495: Lương hiện tại = 12849.3200
# Thế hệ 496: Lương thấp nhất = 12849.3200
# Thế hệ 496: Lương hiện tại = 12849.3200
# Thế hệ 497: Lương thấp nhất = 12849.3200
# Thế hệ 497: Lương hiện tại = 12849.3200
# Thế hệ 498: Lương thấp nhất = 12849.3200
# Thế hệ 498: Lương hiện tại = 12849.3200
# Thế hệ 499: Lương thấp nhất = 12849.3200
# Thế hệ 499: Lương hiện tại = 12849.3200
# Thế hệ 500: Lương thấp nhất = 12849.3200
# Thế hệ 500: Lương hiện tại = 12849.3200

# %%
# Lấy cá thể tốt nhất từ quần thể tốt nhất
best_individual = min(best_population, key=lambda ind: fitness_multi_with_machine_limit(ind) or float('inf'))

# Gán lời giải tốt nhất (nhiều công nhân trên mỗi công đoạn) vào bảng kết quả
dt['Công Nhân Mới (Nhiều)'] = [", ".join(worker_list) for worker_list in best_individual]

# Hiển thị kết quả cuối cùng
dt[['TÊN CÔNG ĐOẠN', 'Công Nhân Mới (Nhiều)']]
# Out:
#                                TÊN CÔNG ĐOẠN            Công Nhân Mới (Nhiều)
# 0                       Xã phà thun lưng - 0                    Ngô Khắc Hiển
# 1   Lấy dấu cắt gai xù túi sau + gọt góc - 0                 Bùi Thị Hồng Vân
# 2                Đo cắt pat túi thân sau - 0                     Trần Thị Cúc
# 3       Đo cắt dây treo gắn túi thân sau - 0  Bùi Thị Hồng Vân, Ngô Khắc Hiển
# 4               Nối dây pat túi thân sau - 1                     Trần Thị Cúc
# ..                                       ...                              ...
# 80                   Vệ sinh công nghiệp - 0                    Ngô Khắc Hiển
# 81           Lộn quần ( trái sang phải ) - 0                    Ngô Khắc Hiển
# 82                     Mí đáy thân trước - 1  Bùi Thị Hồng Vân, Ngô Khắc Hiển
# 83               Lấy dấu lưng thùa khuyu - 0                    Ngô Khắc Hiển
# 84            Uỉ bao túi hông x2+túi sau - 0                     Trần Thị Cúc
#
# [85 rows x 2 columns]

# %%
# Hàm tính lương và tổng tiền lương cho tất cả công nhân
def calculate_salary(individual, proficiency_levels, dt):
    worker_salaries = {worker: 0 for worker in workers}  # Khởi tạo lương cho mỗi công nhân bằng 0

    for task_idx, worker_list in enumerate(individual):
        # Lấy đơn giá của công đoạn hiện tại
        task_price = dt['ĐƠN GIÁ'][task_idx]
        num_workers = len(worker_list)  # Số công nhân thực hiện công đoạn

        # Chia đơn giá cho số công nhân nếu nhiều người thực hiện
        price_per_worker = task_price / num_workers

        # Tính lương cho từng công nhân tham gia công đoạn
        for worker in worker_list:
            proficiency = proficiency_levels[worker]  # Lấy năng lực của công nhân
            # Lương cho công đoạn này bằng đơn giá chia cho số công nhân, sau đó nhân năng lực
            salary_for_task = price_per_worker * proficiency
            # Cộng lương cho công đoạn này vào tổng lương của công nhân
            worker_salaries[worker] += salary_for_task

    # Tạo DataFrame chứa kết quả lương của từng công nhân
    salary_df = pd.DataFrame.from_dict(worker_salaries, orient='index', columns=['Tiền Lương'])
    salary_df.reset_index(inplace=True)
    salary_df.columns = ['Công Nhân', 'Tổng Tiền Lương']

    # Tính tổng tiền lương của tất cả công nhân
    total_salary = salary_df['Tổng Tiền Lương'].sum()
    print(f"Tổng tiền lương của tất cả công nhân: {total_salary:.2f}")

    return salary_df, total_salary
# Sử dụng hàm để tính lương cho mỗi công nhân và tổng lương
salary_df, total_salary = calculate_salary(best_individual, proficiency_levels, dt)

# Hiển thị DataFrame chứa tổng tiền lương cho mỗi công nhân
print(salary_df)
print(f"Tổng tiền lương của tất cả công nhân: {total_salary:.2f}")

# # Giả sử calculate_salary trả về (worker_salaries, total_salary)
# worker_salaries, total_salary = calculate_salary(best_individual, proficiency_levels, dt)

# # In tổng tiền lương của tất cả công nhân
# print(f"Tổng tiền lương của tất cả công nhân: {total_salary:.2f}")

# # In chi tiết lương của từng công nhân
# print("Chi tiết lương của từng công nhân:")
# for worker, row in worker_salaries.iterrows():  # iterrows() giúp lặp qua từng hàng trong DataFrame
#     salary = row['Tổng Tiền Lương']  # Lấy giá trị lương từ cột 'Tổng Tiền Lương'
#     print(f"Công nhân {worker}: Lương = {salary:.2f}")
# Out:
# Tổng tiền lương của tất cả công nhân: 12849.32
#               Công Nhân  Tổng Tiền Lương
# 0    Lê Thị Phương Thảo         0.000000
# 1      Hoàng Thị Mỹ Yến       161.240000
# 2        Trần Thị Tuyền         0.000000
# 3         Ngô Khắc Hiển      3278.500000
# 4           Hồ Thị Diệp         0.000000
# 5   Nguyễn Thị Mỹ Nhung         0.000000
# 6          Thái Thị Nga        19.720000
# 7          Trần Thị Cúc      5449.500000
# 8       Lê Thị Thanh Hà        92.800000
# 9       Nguyễn Thị Thúy        19.720000
# 10     Trần Thị Cẩm Rin         0.000000
# 11         Hoàng Thị Nở        10.826667
# 12     Lê Thị Như Quỳnh        10.826667
# 13      Trần Thị Thương        19.720000
# 14          Đinh Thị Mi         0.000000
# 15  Nguyễn Thị Ngọc Lan       180.960000
# 16     Bùi Thị Hồng Vân      3539.000000
# 17        Trần Thị Oanh        19.720000
# 18       Nguyễn Thị Gấm         0.000000
# 19    Phan Thị Thu Hoài        16.240000
# 20       Nguyễn Thị Thu        19.720000
# 21       Nguyễn Thị Hài        10.826667
# 22      Nguyễn Thị Hồng         0.000000
# Tổng tiền lương của tất cả công nhân: 12849.32

# %%
def display_worker_tasks(individual):
    # Tạo một dictionary lưu trữ các công đoạn mà mỗi công nhân đảm nhiệm
    worker_tasks = {worker: [] for worker in workers}

    # Lặp qua từng công đoạn trong cá thể tốt nhất
    for task_idx, worker_list in enumerate(individual):
        # Lấy tên công đoạn và loại máy cho công đoạn hiện tại
        task_name = dt['TÊN CÔNG ĐOẠN'].iloc[task_idx]  # Sử dụng iloc để tránh lỗi index
        machine_type = machines[task_idx]

        # Thêm công đoạn và loại máy vào danh sách công việc của từng công nhân
        for worker in worker_list:
            worker_tasks[worker].append(f"{task_name} (Máy {machine_type})")

    # Hiển thị kết quả
    for worker, tasks in worker_tasks.items():
        if tasks:  # Nếu công nhân có công việc
            tasks_str = ", ".join(tasks)
            print(f"Công nhân {worker} làm các công đoạn: {tasks_str}")
        else:
            print(f"Công nhân {worker} không có công việc.")

# Gọi hàm hiển thị công việc của từng công nhân cho cá thể tốt nhất
best_individual = min(best_population, key=lambda ind: fitness_multi_with_machine_limit(ind) or float('inf'))

display_worker_tasks(best_individual)
# Out:
# Công nhân Lê Thị Phương Thảo không có công việc.
# Công nhân Hoàng Thị Mỹ Yến làm các công đoạn: Bọ túi hông x4 - 3 (Máy 3), Bọ đáy - 3 (Máy 3)
# Công nhân Trần Thị Tuyền không có công việc.
# Công nhân Ngô Khắc Hiển làm các công đoạn: Xã phà thun lưng - 0 (Máy 0), Đo cắt dây treo gắn túi thân sau - 0 (Máy 0), Ghim miêng túi thân sau vào đáp túi - 1 (Máy 1), Kansai đáy thân sau - 4 (Máy 4), Kẹp mí đáp túi to x2 - 1 (Máy 1), Kẹp mí đáp túi nhỏ x2 - 1 (Máy 1), Diễu 6 ly miệng túi x2 - 1 (Máy 1), Lược bao túi vào thân x2 - 1 (Máy 1), Lấy dấu thun lưng + kéo - 0 (Máy 0), Vs4c sườn thân x2 - 0 (Máy 0), Diễu kan sai đánh bông sườn thân x2 - 4 (Máy 4), diễu kan sai đáy trong - 4 (Máy 4), Lược nhãn tp - 1 (Máy 1), Ghim thun lưng 3 điểm + lấy dấu ( trước + sườn ) - 1 (Máy 1), Chạy kansai lưng - 4 (Máy 4), Lấy dấu may nhãn lưng - 1 (Máy 1), Xỏ dây luồn lưng + so dây - 0 (Máy 0), Thắt nơ dây luồn quần - 0 (Máy 0), Vệ sinh công nghiệp - 0 (Máy 0), Lộn quần ( trái sang phải ) - 0 (Máy 0), Mí đáy thân trước - 1 (Máy 1), Lấy dấu lưng thùa khuyu - 0 (Máy 0)
# Công nhân Hồ Thị Diệp không có công việc.
# Công nhân Nguyễn Thị Mỹ Nhung không có công việc.
# Công nhân Thái Thị Nga làm các công đoạn: Bọ túi thân sau x2 - 3 (Máy 3)
# Công nhân Trần Thị Cúc làm các công đoạn: Đo cắt pat túi thân sau - 0 (Máy 0), Nối dây pat túi thân sau - 1 (Máy 1), Ép dây pat túi thân sau - 2 (Máy 2), Chốt pat túi thân sau - 1 (Máy 1), Gọt lộn dây treo túi sau + lộn - 0 (Máy 0), Ép keo cơi túi - 2 (Máy 2), Bấm góc túi thân sau + chốt 2 đầu cơi túi vào lót túi - 0 (Máy 0), Mí túi thân sau - 1 (Máy 1), Vs3c bao túi thân sau + lộn - 2 (Máy 2), Diễu 6 ly bao túi thân sau + lộn - 1 (Máy 1), Lượ số vs5c decuop vào túi thân sau - 2 (Máy 2), Lựa số + vss5c đecup thân sau - 2 (Máy 2), Láy dấu may gai đáp túi thân sau - 1 (Máy 1), Lựa số + vs4c đáy thân sau+ canh sọc - 2 (Máy 2), Lược miệng túi thân sau - 1 (Máy 1), Vs3c xq túi đồng hồ - 2 (Máy 2), Lược bao túi vào thân x2 - 1 (Máy 1), Vs3c bao túi hông x2+lộn - 2 (Máy 2), Diễu 6 ly bao túi hông x2 + lộn - 1 (Máy 1), Vs3c paget tròn - 2 (Máy 2), Bấm góc vs3c đáy tt - 2 (Máy 2), Nối thun lưng + cắt - 2 (Máy 2), Xã phà thun ống quần - 0 (Máy 0), Chạy thun ống quần x2 + cắt + đo quần - 2 (Máy 2), Lựa số + vs4c sườn thân x2+CANH SỌC - 2 (Máy 2), Vs4c đáy trong - 2 (Máy 2), Lộn quần ( trái sang phải ) - 1 (Máy 1), Gắn nhãn tp - 1 (Máy 1), Ghim thun lưng 3 điểm + lấy dấu ( trước + sườn ) - 1 (Máy 1), Ghim thun lưng 1 điểm + lấy dấu ( sau ) - 1 (Máy 1), Lấy dấu quần lót - 1 (Máy 1), Vs4c quần lót vào quần - 2 (Máy 2), Mí nhãn tp - 0 (Máy 0), May lai quần tp x2 - 1 (Máy 1), Cắt chỉ + gọt lươc gà túi sau - 0 (Máy 0), Uỉ bao túi hông x2+túi sau - 0 (Máy 0)
# Công nhân Lê Thị Thanh Hà làm các công đoạn: Bọ lưng + so dây - 3 (Máy 3)
# Công nhân Nguyễn Thị Thúy làm các công đoạn: Bọ túi thân sau x2 - 3 (Máy 3)
# Công nhân Trần Thị Cẩm Rin không có công việc.
# Công nhân Hoàng Thị Nở làm các công đoạn: Bọ paget tròn x2 - 3 (Máy 3)
# Công nhân Lê Thị Như Quỳnh làm các công đoạn: Bọ paget tròn x2 - 3 (Máy 3)
# Công nhân Trần Thị Thương làm các công đoạn: Bọ túi thân sau x2 - 3 (Máy 3)
# Công nhân Đinh Thị Mi không có công việc.
# Công nhân Nguyễn Thị Ngọc Lan làm các công đoạn: Thùa khuyu lưng x2 - 6 (Máy 6)
# Công nhân Bùi Thị Hồng Vân làm các công đoạn: Lấy dấu cắt gai xù túi sau + gọt góc - 0 (Máy 0), Đo cắt dây treo gắn túi thân sau - 0 (Máy 0), Chốt dây treo túi sau - 1 (Máy 1), Bỏ rập đh cơi túi ( xù, pat, lược tp cơi) - 7 (Máy 7), Kẹp mí đáp túi + bỏ dây treo thân sau + đo gọt đây treo + lấy dấu đáp túi - 1 (Máy 1), Bỏ rập dh túi thân sau + lụa số - 7 (Máy 7), Dieux 2k decuop thân sau x2 - 1 (Máy 1), May nhãn cơi túi thân sau - 1 (Máy 1), Cuốn miệng túi đồng hồ - 1 (Máy 1), Lựa số đóng túi nhỏ vào bao túi - 1 (Máy 1), Bỏ rập đh túi hông x2 + lấy dấu + canh sọc - 7 (Máy 7), Bấm góc miệng túi hông x4 - 1 (Máy 1), Mí âm miêng túi hông x2 - 1 (Máy 1), Lựa số+ ghim miệng túi hông vào đáp túi x4 - 1 (Máy 1), Lược bao túi vào đáy thân trước + 1 đoan paget - 1 (Máy 1), Lựa số+ bỏ rập đh tt + lấy dấu + paget - 7 (Máy 7), Kansai 2 kim ssays thân trước - 1 (Máy 1), Quay paget tròn + đặt rập + ld - 1 (Máy 1), May nhãn logo thân trước + lấy dấu - 7 (Máy 7), Kansai thun ống quần x2 + lộn - 1 (Máy 1), Gấp đôi bấm dấu nhãn tp - 0 (Máy 0), Gỡ chỉ lược - 0 (Máy 0), Lấy dấu laix2 ( sườn trong , ngoài) - 0 (Máy 0), Mí đáy thân trước - 1 (Máy 1)
# Công nhân Trần Thị Oanh làm các công đoạn: Ép keo paget - 5 (Máy 5)
# Công nhân Nguyễn Thị Gấm không có công việc.
# Công nhân Phan Thị Thu Hoài làm các công đoạn: Bọ đáy - 3 (Máy 3)
# Công nhân Nguyễn Thị Thu làm các công đoạn: Ép keo paget - 5 (Máy 5)
# Công nhân Nguyễn Thị Hài làm các công đoạn: Bọ paget tròn x2 - 3 (Máy 3)
# Công nhân Nguyễn Thị Hồng không có công việc.

# %%
# Hàm tính lương và tổng tiền lương cho tất cả công nhân
def calculate_salary(individual, proficiency_levels, dt):
    worker_salaries = {worker: 0 for worker in workers}  # Khởi tạo lương cho mỗi công nhân bằng 0

    for task_idx, worker_list in enumerate(individual):
        # Lấy đơn giá của công đoạn hiện tại
        task_price = dt['ĐƠN GIÁ'][task_idx]
        num_workers = len(worker_list)  # Số công nhân thực hiện công đoạn

        # Chia đơn giá cho số công nhân nếu nhiều người thực hiện
        price_per_worker = task_price / num_workers

        # Tính lương cho từng công nhân tham gia công đoạn
        for worker in worker_list:
            proficiency = proficiency_levels[worker]  # Lấy năng lực của công nhân
            # Lương cho công đoạn này bằng đơn giá chia cho số công nhân, sau đó nhân năng lực
            salary_for_task = price_per_worker * proficiency
            # Cộng lương cho công đoạn này vào tổng lương của công nhân
            worker_salaries[worker] += salary_for_task

    # Tạo DataFrame chứa kết quả lương của từng công nhân
    salary_df = pd.DataFrame.from_dict(worker_salaries, orient='index', columns=['Tiền Lương'])
    salary_df.reset_index(inplace=True)
    salary_df.columns = ['Công Nhân', 'Tổng Tiền Lương']

    # Tính tổng tiền lương của tất cả công nhân
    total_salary = salary_df['Tổng Tiền Lương'].sum()
    print(f"Tổng tiền lương của tất cả công nhân: {total_salary:.2f}")

    return salary_df, total_salary

# Sử dụng hàm để tính lương cho mỗi công nhân và tổng lương
salary_df, total_salary = calculate_salary(best_individual, proficiency_levels, dt)

# Hiển thị DataFrame chứa tổng tiền lương cho mỗi công nhân
print(salary_df)
print(f"Tổng tiền lương của tất cả công nhân: {total_salary:.2f}")
# Out:
# Tổng tiền lương của tất cả công nhân: 12849.32
#               Công Nhân  Tổng Tiền Lương
# 0    Lê Thị Phương Thảo         0.000000
# 1      Hoàng Thị Mỹ Yến       161.240000
# 2        Trần Thị Tuyền         0.000000
# 3         Ngô Khắc Hiển      3278.500000
# 4           Hồ Thị Diệp         0.000000
# 5   Nguyễn Thị Mỹ Nhung         0.000000
# 6          Thái Thị Nga        19.720000
# 7          Trần Thị Cúc      5449.500000
# 8       Lê Thị Thanh Hà        92.800000
# 9       Nguyễn Thị Thúy        19.720000
# 10     Trần Thị Cẩm Rin         0.000000
# 11         Hoàng Thị Nở        10.826667
# 12     Lê Thị Như Quỳnh        10.826667
# 13      Trần Thị Thương        19.720000
# 14          Đinh Thị Mi         0.000000
# 15  Nguyễn Thị Ngọc Lan       180.960000
# 16     Bùi Thị Hồng Vân      3539.000000
# 17        Trần Thị Oanh        19.720000
# 18       Nguyễn Thị Gấm         0.000000
# 19    Phan Thị Thu Hoài        16.240000
# 20       Nguyễn Thị Thu        19.720000
# 21       Nguyễn Thị Hài        10.826667
# 22      Nguyễn Thị Hồng         0.000000
# Tổng tiền lương của tất cả công nhân: 12849.32

# %%
# Hàm tính tổng tiền lương cho cá thể (phân công công nhân)
def calculate_total_salary(individual, proficiency_levels, dt):
    worker_salaries = {worker: 0 for worker in workers}

    for task_idx, worker_list in enumerate(individual):
        task_price = dt['ĐƠN GIÁ'][task_idx]
        num_workers = len(worker_list)
        price_per_worker = task_price / num_workers

        # Tính lương cho từng công nhân dựa trên năng lực
        for worker in worker_list:
            proficiency = proficiency_levels[worker]
            salary_for_task = price_per_worker * proficiency
            worker_salaries[worker] += salary_for_task

    # Tổng tiền lương cho tất cả công nhân trong cá thể này
    total_salary = sum(worker_salaries.values())
    return total_salary

# Khởi tạo quần thể ban đầu
